# %%
import json
import sys

sys.path.append("/Users/chenry/code/ModelSEEDpy")
#from modelseedpy.core.eschermapapi import EscherMapAPI, MSEscherMap
from json import JSONEncoder

class MyEncoder(JSONEncoder):
    def default(self, o):
        return o.__dict__
# Out:
# cobrakbase 0.2.8

# %%
import cobrakbase
kbase = cobrakbase.KBaseAPI()
# Out:
# cobrakbase 0.2.8

# %%
from modelseed_escher.core.eschermapapi import EscherMapAPIBiGG as EscherMapAPI
api = EscherMapAPI()
l = api.list_maps()

# %%
escher_map = api.get_map('iJO1366.Fatty acid biosynthesis (saturated)')

# %%
escher_map.escher_meta
# Out:
# {'map_name': 'iJO1366.Fatty acid biosynthesis (saturated)',
#  'map_id': 'adefea851b1d3aa739c3d3549cecdbe6',
#  'map_description': '\nLast Modified Thu Mar 12 2015 18:18:56 GMT-0700 (PDT)',
#  'homepage': 'https://escher.github.io',
#  'schema': 'https://escher.github.io/escher/jsonschema/1-0-0#'}

# %%
# Out:
# 'adefea851b1d3aa739c3d3549cecdbe6'

# %%
import json
from modelseed_escher.core.eschermapapi import EscherMapAPIBiGG as EscherMapAPI
api = EscherMapAPI()
for map_id in api.list_maps():
    escher_map = api.get_map(map_id)
    kbase_id = map_id.replace(' ', '_').replace('(', '_').replace(')', '_')
    try:
        kbase.save_object(kbase_id, 56171, 'KBaseFBA.EscherMap', escher_map)
    except:
        print(':(', map_id, 'metadata_len', len(json.dumps(escher_map.get_metadata())))
# Out:
# e_coli_core.Core metabolism 682
# iJO1366.Central metabolism 1460
# :( iJO1366.Central metabolism
# iJO1366.Fatty acid beta-oxidation 464
# iJO1366.Nucleotide and histidine biosynthesis 324
# iMM904.Central carbon metabolism 483
# RECON1.Tryptophan metabolism 457
# RECON1.Inositol retinol metabolism 917
# RECON1.Glycolysis TCA PPP 300
# RECON1.Carbohydrate metabolism 2443
# :( RECON1.Carbohydrate metabolism
# iJO1366.Fatty acid biosynthesis (saturated) 491
# RECON1.Amino acid metabolism (partial) 2335
# :( RECON1.Amino acid metabolism (partial)
# iJO1366.Nucleotide metabolism 1691
# :( iJO1366.Nucleotide metabolism

# %%
from modelseed_escher.core.eschermapapi import EscherMapAPIKBase as EscherMapAPI
api = EscherMapAPI(kbase, 56171)

# %%
api.list_maps()
# Out:
# [2, 'AromaticAminoAcidBiosynthesisMap', 'KBaseFBA.EscherMap-1.0', '2020-02-21T03:51:40+0000', 2, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', 'dc7fe42e9f1f709b768033fc2f363678', 48308, {}]
# [14, 'central_carbon', 'KBaseFBA.EscherMap-1.0', '2020-02-24T16:11:22+0000', 3, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', '03935253e39ca72a9a016a99f4eaf15d', 89783, {}]
# [19, 'iJO1366_Central', 'KBaseFBA.EscherMap-1.0', '2020-03-02T21:40:09+0000', 4, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', 'e54b78a7cbecb79cca41e6cfe61b04cd', 366900, {}]
# [25, 'iMM904.Central_carbon_metabolism', 'KBaseFBA.EscherMap-3.0', '2021-06-30T10:20:36+0000', 6, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', 'e2f61bec0686385b179ca99cfe917e85', 130946, {'name': 'iMM904.Central carbon metabolism', 'reactions': 'ACALDt|ACONTm|ACS|ACSm|ACt2r|ACtm|AKGDam|AKGDbm|ALCD2irm|ALCD2x_copy1|ALDD2xm|ALDD2y|ALDD2ym|CITt2r|CITtcm|CO2t|CO2tm|CSm|DPGM|ENO|ETOHt|ETOHtm|FBA|FBA2|FBA3|FBP|FRDm|FRUK|FUMm|FUMt2r|G6PDH2r|GAPD|GCC2cm_copy1|GLCt1|GND|HEX1|ICDHxm|ICDHym|MALt2r|MALtm|MDH|MDHm|ME1m|ME2m|OAAt2m|PC|PDHm|PFK|PFK_3|PGI|PGK|PGL|PGM|PIt2m|PPA|PPAm|PPCK|PYK|PYRDC|PYRt2|PYRt2m|RPE|RPI|SUCCtm|SUCD1m|SUCD2_u6m|SUCFUMtm|SUCOASm|TALA|TKT1|TKT2|TPI'}]
# [31, 'iJO1366.Central_metabolism', 'KBaseFBA.EscherMap-2.0', '2021-06-22T23:44:10+0000', 1, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', '77b8cb1d69c78faaf6d54ece2fadcc6b', 376571, {}]
# [33, 'iMM904.Central_carbon_metabolism.ModelSEEDpy_Escher', 'KBaseFBA.EscherMap-3.0', '2021-06-30T10:15:57+0000', 2, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', 'e2f61bec0686385b179ca99cfe917e85', 130946, {'name': 'iMM904.Central carbon metabolism', 'description': 'Yeast central carbon metabolism\nLast Modified Fri Jan 09 2015 19:50:57 GMT-0800 (PST)', 'reactions': 'ACALDt|ACONTm|ACS|ACSm|ACt2r|ACtm|AKGDam|AKGDbm|ALCD2irm|ALCD2x_copy1|ALDD2xm|ALDD2y|ALDD2ym|CITt2r|CITtcm|CO2t|CO2tm|CSm|DPGM|ENO|ETOHt|ETOHtm|FBA|FBA2|FBA3|FBP|FRDm|FRUK|FUMm|FUMt2r|G6PDH2r|GAPD|GCC2cm_copy1|GLCt1|GND|HEX1|ICDHxm|ICDHym|MALt2r|MALtm|MDH|MDHm|ME1m|ME2m|OAAt2m|PC|PDHm|PFK|PFK_3|PGI|PGK|PGL|PGM|PIt2m|PPA|PPAm|PPCK|PYK|PYRDC|PYRt2|PYRt2m|RPE|RPI|SUCCtm|SUCD1m|SUCD2_u6m|SUCFUMtm|SUCOASm|TALA|TKT1|TKT2|TPI', 'type': ''}]
# [34, 'iJO1366.Nucleotide_and_histidine_biosynthesis', 'KBaseFBA.EscherMap-3.0', '2021-06-30T10:20:36+0000', 4, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', '1d12f0ede4e18f8dca302de1eebad79f', 98534, {'name': 'iJO1366.Nucleotide and histidine biosynthesis', 'reactions': 'ADSL1r|ADSL2r|ADSS|AICART|AIRC2|AIRC3|ASPCT|ATPPRT|CTPS2|DHORDfum|DHORTS|GART|GLUPRT|GMPR|GMPS2|HISTD|HISTP|HSTPT|HXPRT|IG3PS|IGPDH|IMPC|IMPD|INSK|NDPK2|NTD11|NTPP9|OMPDC|ORPT|PPM|PRAGSr|PRAIS|PRAMPC|PRASCSi|PRATPP|PRFGS|PRMICI|PRPPS|R15BPK|R1PK|UMPK'}]
# [35, 'e_coli_core.Core_metabolism', 'KBaseFBA.EscherMap-3.0', '2021-06-30T10:20:35+0000', 4, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', 'a8cbdae7533f624fa786449b1c862914', 152359, {'name': 'e_coli_core.Core metabolism', 'reactions': 'ACALD|ACALDt|ACKr|ACONTa|ACONTb|ACt2r|ADK1|AKGDH|AKGt2r|ALCD2x|ATPM|ATPS4r|BIOMASS_Ecoli_core_w_GAM|CO2t|CS|CYTBD|D_LACt2|ENO|ETOHt2r|EX_ac_e|EX_acald_e|EX_akg_e|EX_co2_e|EX_etoh_e|EX_for_e|EX_fru_e|EX_fum_e|EX_glc__D_e|EX_gln__L_e|EX_glu__L_e|EX_h2o_e|EX_h_e|EX_lac__D_e|EX_mal__L_e|EX_nh4_e|EX_o2_e|EX_pi_e|EX_pyr_e|EX_succ_e|FBA|FBP|FORt2|FORti|FRD7|FRUpts2|FUM|FUMt2_2|G6PDH2r|GAPD|GLCpts|GLNS|GLNabc|GLUDy|GLUN|GLUSy|GLUt2r|GND|H2Ot|ICDHyr|ICL|LDH_D|MALS|MALt2_2|MDH|ME1|ME2|NADH16|NADTRHD|NH4t|O2t|PDH|PFK|PFL|PGI|PGK|PGL|PGM|PIt2r|PPC|PPCK|PPS|PTAr|PYK|PYRt2|RPE|RPI|SUCCt2_2|SUCCt3|SUCDi|SUCOAS|TALA|THD2|TKT1|TKT2|TPI'}]
# [36, 'iJO1366.Fatty_acid_beta-oxidation', 'KBaseFBA.EscherMap-3.0', '2021-06-30T10:20:36+0000', 3, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', '40bba0ecac49aa1e4490f72cc528b7be', 108790, {'name': 'iJO1366.Fatty acid beta-oxidation', 'reactions': 'ACACT1r|ACACT2r|ACACT3r|ACACT4r|ACACT5r|ACACT6r|ACACT7r|ACACT8r|ACOAD1f|ACOAD2f|ACOAD3f|ACOAD4f|ACOAD5f|ACOAD6f|ACOAD7f|ACOAD8f|BUTCT|CTECOAI6|CTECOAI7|CTECOAI8|ECOAH1|ECOAH2|ECOAH3|ECOAH4|ECOAH5|ECOAH6|ECOAH7|ECOAH8|FACOAL100t2pp|FACOAL120t2pp|FACOAL140t2pp|FACOAL141t2pp|FACOAL160t2pp|FACOAL161t2pp|FACOAL180t2pp|FACOAL181t2pp|FACOAL60t2pp|FACOAL80t2pp|HACD1|HACD2|HACD3|HACD4|HACD5|HACD6|HACD7|HACD8'}]
# [37, 'RECON1.Glycolysis_TCA_PPP', 'KBaseFBA.EscherMap-3.0', '2021-06-30T10:20:37+0000', 3, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', '10f36ff788aefc39241a699c389bf228', 73427, {'name': 'RECON1.Glycolysis TCA PPP', 'reactions': 'ACONTm|AKGDm|AKGMALtm|ASPGLUm|ASPTA|ASPTAm|CO2t|CO2tm|CSm|ENO|EX_co2_e|EX_lac__L_e|FBA|FUMm|G6PDH2r|GAPD|GLCt1|GND|HEX1|ICDHxm|LDH_L|L_LACt2r|MDH|MDHm|NDPK1m|PDHm|PFK|PGI|PGK|PGL|PGM|PPM|PRPPS|PYK|PYRt2m|RPE|RPI|SUCD1m|SUCOAS1m|TALA|TKT1|TKT2|TPI'}]
# [38, 'RECON1.Tryptophan_metabolism', 'KBaseFBA.EscherMap-3.0', '2021-06-30T10:20:36+0000', 3, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', '0d71c6bdcb5ec08d549ce48e64ec5d11', 90106, {'name': 'RECON1.Tryptophan metabolism', 'reactions': '2OXOADOXm|2OXOADPTm|3HAO|3HKYNAKGAT|3HXKYNDCL|3HXKYNOXDA|5HLTDL|5HOXINDACTO2OX|5HOXINDACTOX|5HOXINDACTOXm|5HOXINOXDA|5HTRPDOX|5HXKYNDCL|5HXKYNOXDA|ACACT1m|ACACT1r_copy1|ACSOMT|ACSRTNMT|ALDD20x|ALDD20xm|AM6SAD|AMCOXO|ECOAH1m|ECOAH1x|FKYNH|GLUTCOADHm|HACD1m|HACD1x|HKYNH|KYN|KYN3OX|KYNAKGAT|KYNATESYN|LFORKYNHYD|LTDCL|MELATN23DOX|MELATNOX|PCLAD|QUILSYN|SRTN23OX|SRTNACT|SRTNMTX|TRPHYDRO2|TRPO2|TRYPTAOX'}]
# [39, 'RECON1.Inositol_retinol_metabolism', 'KBaseFBA.EscherMap-3.0', '2021-06-30T10:20:37+0000', 3, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', '94a0b19a77d9692eee5be7979df6e0f7', 208713, {'name': 'RECON1.Inositol retinol metabolism', 'reactions': 'BCDO|CAROtr|CDIPTr|HRETNtn|INOSTO|LRAT|LRAT1|LRAT2|MI13456PK|MI13456Ptn|MI1345PKn|MI1345PP|MI1346PKn|MI1346Ptn|MI134P4P|MI134PK|MI134PP|MI13PP|MI1456PKn|MI145P6Kn|MI145PK|MI145PKn|MI145PP|MI14P4P|MI14PP|MI14Ptn|MI1PP|MI1PS|MI3456PK|MI34PP|MI3PP|MI4PP|MINOHPtn|ORETNF|ORETNF2|ORETNtn|PI345P3P|PI345P3Pn|PI345P5P|PI345P5Pn|PI34P3Pn|PI34P4Pn|PI34P5K|PI34P5Kn|PI35P3P|PI3P3Pn|PI3P4K|PI3P4Kn|PI3P5K|PI3PP|PI45P3K|PI45P3Kn|PI45P4P|PI45P5P|PI45P5Pn|PI45PLC|PI45PLCn|PI4P3K|PI4P3Ker|PI4P3Kn|PI4P4Pn|PI4P5K|PI4P5Kn|PI4PLC|PI4PLCn|PI4PP|PI5P3K|PI5P3Ker|PI5P4K|PI5P4Kn|PIK3|PIK3er|PIK3n|PIK4|PIK4n|PIK5|PIK5n|PIPLC|PIPLCn|PMI12346PH|PMI12346PHn|PMI1346PH|PMI1346PHn|RADH|RADH2|RADH3|RADH4|RAHY|RAI1|RAI2|RAI3|RAI4|RAtn|RAtn3|RDH1|RDH1a|RDH2|RDH2a|RDH3|RDH3a|RDH4|RETFA|RETFAt|RETFAt1|RETFAt2|RETH|RETH1|RETH1e|RETH2|RETH2e|RETHe|RETI1|RETI2|RETI3|RETNCOA|RETNt|RETt'}]
# [40, 'iJO1366.Fatty_acid_biosynthesis__saturated_', 'KBaseFBA.EscherMap-3.0', '2021-06-30T10:20:38+0000', 3, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', 'e6cd206ee472ed8e8dc4729d5c1fc964', 130701, {'name': 'iJO1366.Fatty acid biosynthesis (saturated)', 'reactions': '3HAD100|3HAD120|3HAD140|3HAD160|3HAD180|3HAD40|3HAD60|3HAD80|3OAR100|3OAR120|3OAR140|3OAR160|3OAR180|3OAR40|3OAR60|3OAR80|3OAS100|3OAS120|3OAS140|3OAS160|3OAS180|3OAS60|3OAS80|AACPS1|AACPS3|AACPS6|AACPS7|AACPS8|AACPS9|ACCOAC|ACOATA|EAR100x|EAR100y|EAR120x|EAR120y|EAR140x|EAR140y|EAR160x|EAR160y|EAR180x|EAR180y|EAR40x|EAR60x|EAR60y|EAR80x|EAR80y|FA100ACPHi|FA120ACPHi|FA140ACPHi|FA160ACPHi|FA80ACPHi|KAS14|KAS15|MCOATA'}]
# [{'id': 'AromaticAminoAcidBiosynthesisMap',
#   'name': None,
#   'reactions': None,
#   'compounds': None,
#   'type': None,
#   'description': None},
#  {'id': 'central_carbon',
#   'name': None,
#   'reactions': None,
#   'compounds': None,
#   'type': None,
#   'description': None},
#  {'id': 'iJO1366_Central',
#   'name': None,
#   'reactions': None,
#   'compounds': None,
#   'type': None,
#   'description': None},
#  {'id': 'iMM904.Central_carbon_metabolism',
#   'name': 'iMM904.Central carbon metabolism',
#   'reactions': ['ACALDt',
#    'ACONTm',
#    'ACS',
#    'ACSm',
#    'ACt2r',
#    'ACtm',
#    'AKGDam',
#    'AKGDbm',
#    'ALCD2irm',
#    'ALCD2x_copy1',
#    'ALDD2xm',
#    'ALDD2y',
#    'ALDD2ym',
#    'CITt2r',
#    'CITtcm',
#    'CO2t',
#    'CO2tm',
#    'CSm',
#    'DPGM',
#    'ENO',
#    'ETOHt',
#    'ETOHtm',
#    'FBA',
#    'FBA2',
#    'FBA3',
#    'FBP',
#    'FRDm',
#    'FRUK',
#    'FUMm',
#    'FUMt2r',
#    'G6PDH2r',
#    'GAPD',
#    'GCC2cm_copy1',
#    'GLCt1',
#    'GND',
#    'HEX1',
#    'ICDHxm',
#    'ICDHym',
#    'MALt2r',
#    'MALtm',
#    'MDH',
#    'MDHm',
#    'ME1m',
#    'ME2m',
#    'OAAt2m',
#    'PC',
#    'PDHm',
#    'PFK',
#    'PFK_3',
#    'PGI',
#    'PGK',
#    'PGL',
#    'PGM',
#    'PIt2m',
#    'PPA',
#    'PPAm',
#    'PPCK',
#    'PYK',
#    'PYRDC',
#    'PYRt2',
#    'PYRt2m',
#    'RPE',
#    'RPI',
#    'SUCCtm',
#    'SUCD1m',
#    'SUCD2_u6m',
#    'SUCFUMtm',
#    'SUCOASm',
#    'TALA',
#    'TKT1',
#    'TKT2',
#    'TPI'],
#   'compounds': None,
#   'type': None,
#   'description': None},
#  {'id': 'iJO1366.Central_metabolism',
#   'name': None,
#   'reactions': None,
#   'compounds': None,
#   'type': None,
#   'description': None},
#  {'id': 'iMM904.Central_carbon_metabolism.ModelSEEDpy_Escher',
#   'name': 'iMM904.Central carbon metabolism',
#   'reactions': ['ACALDt',
#    'ACONTm',
#    'ACS',
#    'ACSm',
#    'ACt2r',
#    'ACtm',
#    'AKGDam',
#    'AKGDbm',
#    'ALCD2irm',
#    'ALCD2x_copy1',
#    'ALDD2xm',
#    'ALDD2y',
#    'ALDD2ym',
#    'CITt2r',
#    'CITtcm',
#    'CO2t',
#    'CO2tm',
#    'CSm',
#    'DPGM',
#    'ENO',
#    'ETOHt',
#    'ETOHtm',
#    'FBA',
#    'FBA2',
#    'FBA3',
#    'FBP',
#    'FRDm',
#    'FRUK',
#    'FUMm',
#    'FUMt2r',
#    'G6PDH2r',
#    'GAPD',
#    'GCC2cm_copy1',
#    'GLCt1',
#    'GND',
#    'HEX1',
#    'ICDHxm',
#    'ICDHym',
#    'MALt2r',
#    'MALtm',
#    'MDH',
#    'MDHm',
#    'ME1m',
#    'ME2m',
#    'OAAt2m',
#    'PC',
#    'PDHm',
#    'PFK',
#    'PFK_3',
#    'PGI',
#    'PGK',
#    'PGL',
#    'PGM',
#    'PIt2m',
#    'PPA',
#    'PPAm',
#    'PPCK',
#    'PYK',
#    'PYRDC',
#    'PYRt2',
#    'PYRt2m',
#    'RPE',
#    'RPI',
#    'SUCCtm',
#    'SUCD1m',
#    'SUCD2_u6m',
#    'SUCFUMtm',
#    'SUCOASm',
#    'TALA',
#    'TKT1',
#    'TKT2',
#    'TPI'],
#   'compounds': None,
#   'type': '',
#   'description': 'Yeast central carbon metabolism\nLast Modified Fri Jan 09 2015 19:50:57 GMT-0800 (PST)'},
#  {'id': 'iJO1366.Nucleotide_and_histidine_biosynthesis',
#   'name': 'iJO1366.Nucleotide and histidine biosynthesis',
#   'reactions': ['ADSL1r',
#    'ADSL2r',
#    'ADSS',
#    'AICART',
#    'AIRC2',
#    'AIRC3',
#    'ASPCT',
#    'ATPPRT',
#    'CTPS2',
#    'DHORDfum',
#    'DHORTS',
#    'GART',
#    'GLUPRT',
#    'GMPR',
#    'GMPS2',
#    'HISTD',
#    'HISTP',
#    'HSTPT',
#    'HXPRT',
#    'IG3PS',
#    'IGPDH',
#    'IMPC',
#    'IMPD',
#    'INSK',
#    'NDPK2',
#    'NTD11',
#    'NTPP9',
#    'OMPDC',
#    'ORPT',
#    'PPM',
#    'PRAGSr',
#    'PRAIS',
#    'PRAMPC',
#    'PRASCSi',
#    'PRATPP',
#    'PRFGS',
#    'PRMICI',
#    'PRPPS',
#    'R15BPK',
#    'R1PK',
#    'UMPK'],
#   'compounds': None,
#   'type': None,
#   'description': None},
#  {'id': 'e_coli_core.Core_metabolism',
#   'name': 'e_coli_core.Core metabolism',
#   'reactions': ['ACALD',
#    'ACALDt',
#    'ACKr',
#    'ACONTa',
#    'ACONTb',
#    'ACt2r',
#    'ADK1',
#    'AKGDH',
#    'AKGt2r',
#    'ALCD2x',
#    'ATPM',
#    'ATPS4r',
#    'BIOMASS_Ecoli_core_w_GAM',
#    'CO2t',
#    'CS',
#    'CYTBD',
#    'D_LACt2',
#    'ENO',
#    'ETOHt2r',
#    'EX_ac_e',
#    'EX_acald_e',
#    'EX_akg_e',
#    'EX_co2_e',
#    'EX_etoh_e',
#    'EX_for_e',
#    'EX_fru_e',
#    'EX_fum_e',
#    'EX_glc__D_e',
#    'EX_gln__L_e',
#    'EX_glu__L_e',
#    'EX_h2o_e',
#    'EX_h_e',
#    'EX_lac__D_e',
#    'EX_mal__L_e',
#    'EX_nh4_e',
#    'EX_o2_e',
#    'EX_pi_e',
#    'EX_pyr_e',
#    'EX_succ_e',
#    'FBA',
#    'FBP',
#    'FORt2',
#    'FORti',
#    'FRD7',
#    'FRUpts2',
#    'FUM',
#    'FUMt2_2',
#    'G6PDH2r',
#    'GAPD',
#    'GLCpts',
#    'GLNS',
#    'GLNabc',
#    'GLUDy',
#    'GLUN',
#    'GLUSy',
#    'GLUt2r',
#    'GND',
#    'H2Ot',
#    'ICDHyr',
#    'ICL',
#    'LDH_D',
#    'MALS',
#    'MALt2_2',
#    'MDH',
#    'ME1',
#    'ME2',
#    'NADH16',
#    'NADTRHD',
#    'NH4t',
#    'O2t',
#    'PDH',
#    'PFK',
#    'PFL',
#    'PGI',
#    'PGK',
#    'PGL',
#    'PGM',
#    'PIt2r',
#    'PPC',
#    'PPCK',
#    'PPS',
#    'PTAr',
#    'PYK',
#    'PYRt2',
#    'RPE',
#    'RPI',
#    'SUCCt2_2',
#    'SUCCt3',
#    'SUCDi',
#    'SUCOAS',
#    'TALA',
#    'THD2',
#    'TKT1',
#    'TKT2',
#    'TPI'],
#   'compounds': None,
#   'type': None,
#   'description': None},
#  {'id': 'iJO1366.Fatty_acid_beta-oxidation',
#   'name': 'iJO1366.Fatty acid beta-oxidation',
#   'reactions': ['ACACT1r',
#    'ACACT2r',
#    'ACACT3r',
#    'ACACT4r',
#    'ACACT5r',
#    'ACACT6r',
#    'ACACT7r',
#    'ACACT8r',
#    'ACOAD1f',
#    'ACOAD2f',
#    'ACOAD3f',
#    'ACOAD4f',
#    'ACOAD5f',
#    'ACOAD6f',
#    'ACOAD7f',
#    'ACOAD8f',
#    'BUTCT',
#    'CTECOAI6',
#    'CTECOAI7',
#    'CTECOAI8',
#    'ECOAH1',
#    'ECOAH2',
#    'ECOAH3',
#    'ECOAH4',
#    'ECOAH5',
#    'ECOAH6',
#    'ECOAH7',
#    'ECOAH8',
#    'FACOAL100t2pp',
#    'FACOAL120t2pp',
#    'FACOAL140t2pp',
#    'FACOAL141t2pp',
#    'FACOAL160t2pp',
#    'FACOAL161t2pp',
#    'FACOAL180t2pp',
#    'FACOAL181t2pp',
#    'FACOAL60t2pp',
#    'FACOAL80t2pp',
#    'HACD1',
#    'HACD2',
#    'HACD3',
#    'HACD4',
#    'HACD5',
#    'HACD6',
#    'HACD7',
#    'HACD8'],
#   'compounds': None,
#   'type': None,
#   'description': None},
#  {'id': 'RECON1.Glycolysis_TCA_PPP',
#   'name': 'RECON1.Glycolysis TCA PPP',
#   'reactions': ['ACONTm',
#    'AKGDm',
#    'AKGMALtm',
#    'ASPGLUm',
#    'ASPTA',
#    'ASPTAm',
#    'CO2t',
#    'CO2tm',
#    'CSm',
#    'ENO',
#    'EX_co2_e',
#    'EX_lac__L_e',
#    'FBA',
#    'FUMm',
#    'G6PDH2r',
#    'GAPD',
#    'GLCt1',
#    'GND',
#    'HEX1',
#    'ICDHxm',
#    'LDH_L',
#    'L_LACt2r',
#    'MDH',
#    'MDHm',
#    'NDPK1m',
#    'PDHm',
#    'PFK',
#    'PGI',
#    'PGK',
#    'PGL',
#    'PGM',
#    'PPM',
#    'PRPPS',
#    'PYK',
#    'PYRt2m',
#    'RPE',
#    'RPI',
#    'SUCD1m',
#    'SUCOAS1m',
#    'TALA',
#    'TKT1',
#    'TKT2',
#    'TPI'],
#   'compounds': None,
#   'type': None,
#   'description': None},
#  {'id': 'RECON1.Tryptophan_metabolism',
#   'name': 'RECON1.Tryptophan metabolism',
#   'reactions': ['2OXOADOXm',
#    '2OXOADPTm',
#    '3HAO',
#    '3HKYNAKGAT',
#    '3HXKYNDCL',
#    '3HXKYNOXDA',
#    '5HLTDL',
#    '5HOXINDACTO2OX',
#    '5HOXINDACTOX',
#    '5HOXINDACTOXm',
#    '5HOXINOXDA',
#    '5HTRPDOX',
#    '5HXKYNDCL',
#    '5HXKYNOXDA',
#    'ACACT1m',
#    'ACACT1r_copy1',
#    'ACSOMT',
#    'ACSRTNMT',
#    'ALDD20x',
#    'ALDD20xm',
#    'AM6SAD',
#    'AMCOXO',
#    'ECOAH1m',
#    'ECOAH1x',
#    'FKYNH',
#    'GLUTCOADHm',
#    'HACD1m',
#    'HACD1x',
#    'HKYNH',
#    'KYN',
#    'KYN3OX',
#    'KYNAKGAT',
#    'KYNATESYN',
#    'LFORKYNHYD',
#    'LTDCL',
#    'MELATN23DOX',
#    'MELATNOX',
#    'PCLAD',
#    'QUILSYN',
#    'SRTN23OX',
#    'SRTNACT',
#    'SRTNMTX',
#    'TRPHYDRO2',
#    'TRPO2',
#    'TRYPTAOX'],
#   'compounds': None,
#   'type': None,
#   'description': None},
#  {'id': 'RECON1.Inositol_retinol_metabolism',
#   'name': 'RECON1.Inositol retinol metabolism',
#   'reactions': ['BCDO',
#    'CAROtr',
#    'CDIPTr',
#    'HRETNtn',
#    'INOSTO',
#    'LRAT',
#    'LRAT1',
#    'LRAT2',
#    'MI13456PK',
#    'MI13456Ptn',
#    'MI1345PKn',
#    'MI1345PP',
#    'MI1346PKn',
#    'MI1346Ptn',
#    'MI134P4P',
#    'MI134PK',
#    'MI134PP',
#    'MI13PP',
#    'MI1456PKn',
#    'MI145P6Kn',
#    'MI145PK',
#    'MI145PKn',
#    'MI145PP',
#    'MI14P4P',
#    'MI14PP',
#    'MI14Ptn',
#    'MI1PP',
#    'MI1PS',
#    'MI3456PK',
#    'MI34PP',
#    'MI3PP',
#    'MI4PP',
#    'MINOHPtn',
#    'ORETNF',
#    'ORETNF2',
#    'ORETNtn',
#    'PI345P3P',
#    'PI345P3Pn',
#    'PI345P5P',
#    'PI345P5Pn',
#    'PI34P3Pn',
#    'PI34P4Pn',
#    'PI34P5K',
#    'PI34P5Kn',
#    'PI35P3P',
#    'PI3P3Pn',
#    'PI3P4K',
#    'PI3P4Kn',
#    'PI3P5K',
#    'PI3PP',
#    'PI45P3K',
#    'PI45P3Kn',
#    'PI45P4P',
#    'PI45P5P',
#    'PI45P5Pn',
#    'PI45PLC',
#    'PI45PLCn',
#    'PI4P3K',
#    'PI4P3Ker',
#    'PI4P3Kn',
#    'PI4P4Pn',
#    'PI4P5K',
#    'PI4P5Kn',
#    'PI4PLC',
#    'PI4PLCn',
#    'PI4PP',
#    'PI5P3K',
#    'PI5P3Ker',
#    'PI5P4K',
#    'PI5P4Kn',
#    'PIK3',
#    'PIK3er',
#    'PIK3n',
#    'PIK4',
#    'PIK4n',
#    'PIK5',
#    'PIK5n',
#    'PIPLC',
#    'PIPLCn',
#    'PMI12346PH',
#    'PMI12346PHn',
#    'PMI1346PH',
#    'PMI1346PHn',
#    'RADH',
#    'RADH2',
#    'RADH3',
#    'RADH4',
#    'RAHY',
#    'RAI1',
#    'RAI2',
#    'RAI3',
#    'RAI4',
#    'RAtn',
#    'RAtn3',
#    'RDH1',
#    'RDH1a',
#    'RDH2',
#    'RDH2a',
#    'RDH3',
#    'RDH3a',
#    'RDH4',
#    'RETFA',
#    'RETFAt',
#    'RETFAt1',
#    'RETFAt2',
#    'RETH',
#    'RETH1',
#    'RETH1e',
#    'RETH2',
#    'RETH2e',
#    'RETHe',
#    'RETI1',
#    'RETI2',
#    'RETI3',
#    'RETNCOA',
#    'RETNt',
#    'RETt'],
#   'compounds': None,
#   'type': None,
#   'description': None},
#  {'id': 'iJO1366.Fatty_acid_biosynthesis__saturated_',
#   'name': 'iJO1366.Fatty acid biosynthesis (saturated)',
#   'reactions': ['3HAD100',
#    '3HAD120',
#    '3HAD140',
#    '3HAD160',
#    '3HAD180',
#    '3HAD40',
#    '3HAD60',
#    '3HAD80',
#    '3OAR100',
#    '3OAR120',
#    '3OAR140',
#    '3OAR160',
#    '3OAR180',
#    '3OAR40',
#    '3OAR60',
#    '3OAR80',
#    '3OAS100',
#    '3OAS120',
#    '3OAS140',
#    '3OAS160',
#    '3OAS180',
#    '3OAS60',
#    '3OAS80',
#    'AACPS1',
#    'AACPS3',
#    'AACPS6',
#    'AACPS7',
#    'AACPS8',
#    'AACPS9',
#    'ACCOAC',
#    'ACOATA',
#    'EAR100x',
#    'EAR100y',
#    'EAR120x',
#    'EAR120y',
#    'EAR140x',
#    'EAR140y',
#    'EAR160x',
#    'EAR160y',
#    'EAR180x',
#    'EAR180y',
#    'EAR40x',
#    'EAR60x',
#    'EAR60y',
#    'EAR80x',
#    'EAR80y',
#    'FA100ACPHi',
#    'FA120ACPHi',
#    'FA140ACPHi',
#    'FA160ACPHi',
#    'FA80ACPHi',
#    'KAS14',
#    'KAS15',
#    'MCOATA'],
#   'compounds': None,
#   'type': None,
#   'description': None}]

# %%
api = EscherMapAPI(kbase, 56171)

# %%
api.list_maps()
# Out:
# [2, 'AromaticAminoAcidBiosynthesisMap', 'KBaseFBA.EscherMap-1.0', '2020-02-21T03:51:40+0000', 2, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', 'dc7fe42e9f1f709b768033fc2f363678', 48308, {}]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-8-47bbf96535dc> in <module>
# ----> 1 api.list_maps()
#
# /usr/local/lib/python3.8/site-packages/modelseed_escher/core/eschermapapi.py in list_maps(self, workspaces)
#      95             if "description" in item[10]:
#      96                 description = item[10]["description"]
# ---> 97             newmap = MSEscherMap(item[1],name,description,type,reactions,item[7])
#      98             output.append(newmap)
#      99         return output
#
# UnboundLocalError: local variable 'description' referenced before assignment

# %%
def list_maps(kbase, workspaces=None):
    if workspaces is None:
        workspaces = [self.default_workspace]
    input = {
        "workspaces": [],
        "ids": [],
        'includeMetadata': 1,
        "type": "KBaseFBA.EscherMap"
    }
    for workspace in workspaces:
        if isinstance(workspace, int):
            input["ids"].append(workspace)
        else:
            input["workspaces"].append(workspace)

    map_list = kbase.ws_client.list_objects(input)
    output = []
    for item in map_list:
        print(item)
        name = None
        reactions = None
        type = None
        if "name" in item[10]:
            name = item[10]["name"]
        if "reactions" in item[10]:
            reactions = item[10]["reactions"].split("|")
        if "type" in item[10]:
            type = item[10]["type"]
        if "description" in item[10]:
            description = item[10]["description"]
        #newmap = MSEscherMap(item[1],name,description,type,reactions,item[7])
        output.append({
            'id': item[1],
            'name': item[10]["name"] if "name" in item[10] else None,
            'reactions': item[10]["reactions"].split("|") if "reactions" in item[10] else None,
            'compounds': item[10]["reactions"].split("|") if "compounds" in item[10] else None,
            'type': item[10]["type"] if "type" in item[10] else None,
            'description': item[10]["description"] if "description" in item[10] else None,
        })
    return output
list_maps(kbase, [56171])
# Out:
# [2, 'AromaticAminoAcidBiosynthesisMap', 'KBaseFBA.EscherMap-1.0', '2020-02-21T03:51:40+0000', 2, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', 'dc7fe42e9f1f709b768033fc2f363678', 48308, {}]
# [14, 'central_carbon', 'KBaseFBA.EscherMap-1.0', '2020-02-24T16:11:22+0000', 3, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', '03935253e39ca72a9a016a99f4eaf15d', 89783, {}]
# [19, 'iJO1366_Central', 'KBaseFBA.EscherMap-1.0', '2020-03-02T21:40:09+0000', 4, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', 'e54b78a7cbecb79cca41e6cfe61b04cd', 366900, {}]
# [25, 'iMM904.Central_carbon_metabolism', 'KBaseFBA.EscherMap-2.0', '2021-06-22T23:21:54+0000', 3, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', '7034ba4e9edb0a751fe1ed931d12c73d', 824867, {}]
# [31, 'iJO1366.Central_metabolism', 'KBaseFBA.EscherMap-2.0', '2021-06-22T23:44:10+0000', 1, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', '77b8cb1d69c78faaf6d54ece2fadcc6b', 376571, {}]
# [33, 'iMM904.Central_carbon_metabolism.ModelSEEDpy_Escher', 'KBaseFBA.EscherMap-3.0', '2021-06-30T09:56:45+0000', 1, 'filipeliu', 56171, 'filipeliu:narrative_1582257065401', 'e2f61bec0686385b179ca99cfe917e85', 130946, {'name': 'iMM904.Central carbon metabolism', 'description': 'Yeast central carbon metabolism\nLast Modified Fri Jan 09 2015 19:50:57 GMT-0800 (PST)', 'reactions': 'ACALDt|ACONTm|ACS|ACSm|ACt2r|ACtm|AKGDam|AKGDbm|ALCD2irm|ALCD2x_copy1|ALDD2xm|ALDD2y|ALDD2ym|CITt2r|CITtcm|CO2t|CO2tm|CSm|DPGM|ENO|ETOHt|ETOHtm|FBA|FBA2|FBA3|FBP|FRDm|FRUK|FUMm|FUMt2r|G6PDH2r|GAPD|GCC2cm_copy1|GLCt1|GND|HEX1|ICDHxm|ICDHym|MALt2r|MALtm|MDH|MDHm|ME1m|ME2m|OAAt2m|PC|PDHm|PFK|PFK_3|PGI|PGK|PGL|PGM|PIt2m|PPA|PPAm|PPCK|PYK|PYRDC|PYRt2|PYRt2m|RPE|RPI|SUCCtm|SUCD1m|SUCD2_u6m|SUCFUMtm|SUCOASm|TALA|TKT1|TKT2|TPI', 'type': ''}]
# [{'id': 'AromaticAminoAcidBiosynthesisMap',
#   'name': None,
#   'reactions': None,
#   'type': None,
#   'description': None},
#  {'id': 'central_carbon',
#   'name': None,
#   'reactions': None,
#   'type': None,
#   'description': None},
#  {'id': 'iJO1366_Central',
#   'name': None,
#   'reactions': None,
#   'type': None,
#   'description': None},
#  {'id': 'iMM904.Central_carbon_metabolism',
#   'name': None,
#   'reactions': None,
#   'type': None,
#   'description': None},
#  {'id': 'iJO1366.Central_metabolism',
#   'name': None,
#   'reactions': None,
#   'type': None,
#   'description': None},
#  {'id': 'iMM904.Central_carbon_metabolism.ModelSEEDpy_Escher',
#   'name': 'iMM904.Central carbon metabolism',
#   'reactions': ['ACALDt',
#    'ACONTm',
#    'ACS',
#    'ACSm',
#    'ACt2r',
#    'ACtm',
#    'AKGDam',
#    'AKGDbm',
#    'ALCD2irm',
#    'ALCD2x_copy1',
#    'ALDD2xm',
#    'ALDD2y',
#    'ALDD2ym',
#    'CITt2r',
#    'CITtcm',
#    'CO2t',
#    'CO2tm',
#    'CSm',
#    'DPGM',
#    'ENO',
#    'ETOHt',
#    'ETOHtm',
#    'FBA',
#    'FBA2',
#    'FBA3',
#    'FBP',
#    'FRDm',
#    'FRUK',
#    'FUMm',
#    'FUMt2r',
#    'G6PDH2r',
#    'GAPD',
#    'GCC2cm_copy1',
#    'GLCt1',
#    'GND',
#    'HEX1',
#    'ICDHxm',
#    'ICDHym',
#    'MALt2r',
#    'MALtm',
#    'MDH',
#    'MDHm',
#    'ME1m',
#    'ME2m',
#    'OAAt2m',
#    'PC',
#    'PDHm',
#    'PFK',
#    'PFK_3',
#    'PGI',
#    'PGK',
#    'PGL',
#    'PGM',
#    'PIt2m',
#    'PPA',
#    'PPAm',
#    'PPCK',
#    'PYK',
#    'PYRDC',
#    'PYRt2',
#    'PYRt2m',
#    'RPE',
#    'RPI',
#    'SUCCtm',
#    'SUCD1m',
#    'SUCD2_u6m',
#    'SUCFUMtm',
#    'SUCOASm',
#    'TALA',
#    'TKT1',
#    'TKT2',
#    'TPI'],
#   'type': '',
#   'description': 'Yeast central carbon metabolism\nLast Modified Fri Jan 09 2015 19:50:57 GMT-0800 (PST)'}]

# %%
print(api.list_maps())
# Out:
# {'RECON1.Amino acid metabolism (partial)',
#  'RECON1.Carbohydrate metabolism',
#  'RECON1.Glycolysis TCA PPP',
#  'RECON1.Inositol retinol metabolism',
#  'RECON1.Tryptophan metabolism',
#  'e_coli_core.Core metabolism',
#  'iJO1366.Central metabolism',
#  'iJO1366.Fatty acid beta-oxidation',
#  'iJO1366.Fatty acid biosynthesis (saturated)',
#  'iJO1366.Nucleotide and histidine biosynthesis',
#  'iJO1366.Nucleotide metabolism',
#  'iMM904.Central carbon metabolism'}

# %%
print(escher_map)
# Out:
# <EscherMap iMM904.Central carbon metabolism at 0x7fa760651a00>

# %%
from modelseed_escher.io.json import load_json_map

# %%
escher_map = load_json_map('example_map.json')

# %%
import escher

# %%
escher_map.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="ikjskaiwyd"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"ikjskaiwyd"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": null, "metabolite_data": null, "gene_data": null}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"authors": ["chenry"], "map_name": "ModelSEED.Trehalose Uptake and Utilization", "map_id": "o0u5z7uvvADq", "map_description": "Trehalose Uptake and Utilization\\nLast Modified Mon Jun 28 2021 10:12:34 GMT-0500 (Central Daylight Time)", "homepage": "https://escher.github.io", "schema": "https://escher.github.io/escher/jsonschema/1-0-0#"}, {"reactions": {"3": {"name": "rxn01967", "bigg_id": "rxn01967", "reversibility": 1, "label_x": -652.6898321965753, "label_y": -658.75013055728, "gene_reaction_rule": "", "genes": [], "metabolites": [{"bigg_id": "cpd00501", "coefficient": -1}, {"bigg_id": "cpd00863", "coefficient": 1}], "annotation": {"seed.compartment": "0:", "seed.reaction": ["rxn01967"]}, "segments": {"19": {"from_node_id": "23", "to_node_id": "24", "b1": null, "b2": null}, "20": {"from_node_id": "25", "to_node_id": "24", "b1": null, "b2": null}, "21": {"from_node_id": "23", "to_node_id": "79", "b1": {"x": -508.37478818840714, "y": -629.2011118470602}, "b2": {"x": -505.19875824628224, "y": -515.8052208256784}}, "22": {"from_node_id": "25", "to_node_id": "26", "b1": {"x": -509.2598810875547, "y": -753.1979529784359}, "b2": {"x": -509.4486539012666, "y": -825.2375375696347}}}}, "4": {"name": "rxn02004", "bigg_id": "rxn02004", "reversibility": 1, "label_x": 1206.3065387878232, "label_y": -183.3986825013913, "gene_reaction_rule": "", "genes": [], "metabolites": [{"bigg_id": "cpd00001", "coefficient": -1}, {"bigg_id": "cpd00523", "coefficient": -1}, {"bigg_id": "cpd00009", "coefficient": 1}, {"bigg_id": "cpd00794", "coefficient": 1}], "annotation": {"seed.compartment": "0:", "seed.reaction": ["rxn02004"]}, "segments": {"23": {"from_node_id": "28", "to_node_id": "29", "b1": null, "b2": null}, "24": {"from_node_id": "30", "to_node_id": "29", "b1": null, "b2": null}, "25": {"from_node_id": "28", "to_node_id": "27", "b1": {"x": 1356.4309843036165, "y": -258.8489669657092}, "b2": {"x": 1366.483827679275, "y": -284.82919985565877}}, "26": {"from_node_id": "28", "to_node_id": "57", "b1": {"x": 1371.5807610321535, "y": -1083.28759176581}, "b2": {"x": 1226.1805426173148, "y": -1408.2694084322843}}, "27": {"from_node_id": "30", "to_node_id": "32", "b1": {"x": 1357.784447593591, "y": -130.856122880101}, "b2": {"x": 1394.112790876443, "y": -125.75782393665509}}, "28": {"from_node_id": "30", "to_node_id": "45", "b1": {"x": 1362.8900857905458, "y": 465.56070036020515}, "b2": {"x": 859.3356632188836, "y": 678.4004524640743}}}}, "5": {"name": "rxn15550", "bigg_id": "rxn15550", "reversibility": 0, "label_x": -353.796182446255, "label_y": -1175.948413281249, "gene_reaction_rule": "", "genes": [], "metabolites": [{"bigg_id": "cpd00009", "coefficient": -1}, {"bigg_id": "cpd00523", "coefficient": -1}, {"bigg_id": "cpd00501", "coefficient": 1}, {"bigg_id": "cpd19006", "coefficient": 1}], "annotation": {"seed.compartment": "0:", "seed.reaction": ["rxn15550"]}, "segments": {"29": {"from_node_id": "35", "to_node_id": "36", "b1": null, "b2": null}, "30": {"from_node_id": "37", "to_node_id": "36", "b1": null, "b2": null}, "31": {"from_node_id": "35", "to_node_id": "34", "b1": {"x": -370.4426885268074, "y": -1247.926546664939}, "b2": {"x": -385.6192338103945, "y": -1267.8136642781812}}, "32": {"from_node_id": "35", "to_node_id": "57", "b1": {"x": -370.5489147255523, "y": -1251.9251359155}, "b2": {"x": -375.823801988804, "y": -1444.6754263271105}}, "33": {"from_node_id": "37", "to_node_id": "79", "b1": {"x": -360.0092845622239, "y": -942.7660128005407}, "b2": {"x": -355.2586345871893, "y": -447.11649165239726}}, "34": {"from_node_id": "37", "to_node_id": "59", "b1": {"x": -363.3480536904281, "y": -1011.8296177354371}, "b2": {"x": -145.7802623808946, "y": -1081.3492531582183}}}}, "6": {"name": "rxn00007", "bigg_id": "rxn00007", "reversibility": 0, "label_x": 156.02239087318674, "label_y": 152.13171551400717, "gene_reaction_rule": "", "genes": [], "metabolites": [{"bigg_id": "cpd00001", "coefficient": -1}, {"bigg_id": "cp ...

# %%
#escher_map.reactions

# %%
escher_map
# Out:
# dict_values([{'node_type': 'multimarker', 'x': -508.67457771876377, 'y': -671.2000419076874}, {'node_type': 'midmarker', 'x': -508.8173346379814, 'y': -691.1995324127488}, {'node_type': 'multimarker', 'x': -508.96009155719815, 'y': -711.199022917809}, {'node_type': 'metabolite', 'x': -509.8680023514683, 'y': -883.9860409282512, 'bigg_id': 'cpd00863', 'name': 'beta-D-Glucose 6-phosphate', 'label_x': -700.7273468338901, 'label_y': -916.7966488384075, 'node_is_primary': 1}, {'node_type': 'metabolite', 'x': 1459.4825355701012, 'y': -353.09053276978943, 'bigg_id': 'cpd00001', 'name': 'H2O', 'label_x': 1450.0809242419762, 'label_y': -378.72200249635193, 'node_is_primary': 0}, {'node_type': 'multimarker', 'x': 1356.8750894456393, 'y': -216.8513150001187}, {'node_type': 'midmarker', 'x': 1357.0865680846982, 'y': -196.85243311174287}, {'node_type': 'multimarker', 'x': 1357.2980467237567, 'y': -176.85355122336597}, {'node_type': 'metabolite', 'x': 1461.8465437138939, 'y': -83.35531261402309, 'bigg_id': 'cpd00009', 'name': 'Phosphate', 'label_x': 1414.0228132451439, 'label_y': -46.06625392872036, 'node_is_primary': 0}, {'node_type': 'metabolite', 'x': -469.54595942837904, 'y': -1324.2364313366174, 'bigg_id': 'cpd00009', 'name': 'Phosphate', 'label_x': -531.0529174361916, 'label_y': -1340.082988953805, 'node_is_primary': 0}, {'node_type': 'multimarker', 'x': -369.32731343998125, 'y': -1205.9413595340516}, {'node_type': 'midmarker', 'x': -368.796182446255, 'y': -1185.948413281249}, {'node_type': 'multimarker', 'x': -368.26505145252844, 'y': -1165.9554670284465}, {'node_type': 'metabolite', 'x': 214.52729258356703, 'y': 353.3448513244198, 'bigg_id': 'cpd00001', 'name': 'H2O', 'label_x': 239.52729258356726, 'label_y': 353.3448513244198, 'node_is_primary': 0}, {'node_type': 'multimarker', 'x': 141.16514779240435, 'y': 162.13120601906843}, {'node_type': 'midmarker', 'x': 141.02239087318674, 'y': 142.13171551400717}, {'node_type': 'multimarker', 'x': 140.87963395396957, 'y': 122.13222500894659}, {'node_type': 'metabolite', 'x': -282.5193387117723, 'y': 721.1040275179624, 'bigg_id': 'cpd00794', 'name': 'TRHL', 'label_x': -313.16869173911607, 'label_y': 768.3308951937437, 'node_is_primary': 1}, {'node_type': 'metabolite', 'x': 139.77326783003468, 'y': -32.86382640527415, 'bigg_id': 'cpd00027', 'name': 'D-Glucose', 'label_x': 163.04640015425343, 'label_y': -3.5069500319831377, 'node_is_primary': 1}, {'node_type': 'metabolite', 'x': -86.02948503079739, 'y': 353.8676454739167, 'bigg_id': 'cpd00001', 'name': 'H2O', 'label_x': -110.72861222806301, 'label_y': 334.9346620754792, 'node_is_primary': 0}, {'node_type': 'multimarker', 'x': -147.27827931884073, 'y': 172.61649678537225}, {'node_type': 'midmarker', 'x': -147.4210362380585, 'y': 152.61700628031178}, {'node_type': 'multimarker', 'x': -147.56379315727588, 'y': 132.61751577525087}, {'node_type': 'metabolite', 'x': -151.36270364046928, 'y': -33.473551951543186, 'bigg_id': 'cpd19001', 'name': 'alpha-D-Glucose', 'label_x': -147.34064896822804, 'label_y': -6.862497531071995, 'node_is_primary': 1}, {'node_type': 'metabolite', 'x': 375.9383774363421, 'y': -574.5437020385291, 'bigg_id': 'cpd00001', 'name': 'H2O', 'label_x': 354.3127670847796, 'label_y': -588.3587044799353, 'node_is_primary': 0}, {'node_type': 'multimarker', 'x': 460.4502601000155, 'y': -530.3797905574959}, {'node_type': 'midmarker', 'x': 461.0295236651549, 'y': -510.38818097442095}, {'node_type': 'multimarker', 'x': 461.6087872302935, 'y': -490.3965713913451}, {'node_type': 'metabolite', 'x': -163.05344606753388, 'y': -1467.412498478513, 'bigg_id': 'cpd00523', 'name': 'Trehalose 6-phosphate', 'label_x': -297.1999914776901, 'label_y': -1492.2201767011693, 'node_is_primary': 1}, {'node_type': 'metabolite', 'x': -146.40750325159055, 'y': -877.6539544723469, 'bigg_id': 'cpd19006', 'name': 'alpha-D-Glucose 6-phosphate', 'label_x': -273.0507108016394, 'label_y': -901.362610783382, 'node_is_primary': 1}, {'node_type': 'metabolite', 'x': 932.0794 ...

# %%
kbase_api = cobrakbase.KBaseAPI()
mapapi = EscherMapAPI(kbase_api)

data = {}
with open('/Users/chenry/code/ModelSEEDpy/examples/example_map.json') as json_file:
    data = json.load(json_file)
newmap = MSEscherMap(data[0]["map_id"])
newmap.set_attributes_from_data(data)

newmap.type = "Pathway"

mapapi.save_map(newmap)

maplist = mapapi.list_maps()
print(json.dumps(maplist,cls=MyEncoder,indent=2))
    
savedmap = mapapi.get_maps([newmap.id])
print(json.dumps(savedmap,cls=MyEncoder,indent=2))
# Out:
# [
#   {
#     "id": "o0u5z7uvvADq",
#     "name": "ModelSEED.Trehalose Uptake and Utilization",
#     "description": "Trehalose Uptake and Utilization\nLast Modified Mon Jun 28 2021 10:12:34 GMT-0500 (Central Daylight Time)",
#     "type": "Pathway",
#     "reactions": [
#       "rxn01967",
#       "rxn02004",
#       "rxn15550",
#       "rxn00007",
#       "rxn15002",
#       "rxn15073",
#       "rxn15074",
#       "rxn15360",
#       "rxn04020",
#       "rxn27381",
#       "rxn15001",
#       "rxn01966",
#       "rxn39802",
#       "rxn00704",
#       "rxn27702",
#       "rxn00606",
#       "rxn00216",
#       "rxn11965"
#     ],
#     "workspace": "chenry:narrative_1624896051323",
#     "data": null
#   }
# ]
# [
#   {
#     "id": "o0u5z7uvvADq",
#     "name": "ModelSEED.Trehalose Uptake and Utilization",
#     "description": "Trehalose Uptake and Utilization\nLast Modified Mon Jun 28 2021 10:12:34 GMT-0500 (Central Daylight Time)",
#     "type": "Pathway",
#     "reactions": [
#       "rxn15360",
#       "rxn04020",
#       "rxn27381",
#       "rxn15001",
#       "rxn01966",
#       "rxn39802",
#       "rxn00704",
#       "rxn27702",
#       "rxn00606",
#       "rxn00216",
#       "rxn11965",
#       "rxn01967",
#       "rxn02004",
#       "rxn15550",
#       "rxn00007",
#       "rxn15002",
#       "rxn15073",
#       "rxn15074"
#     ],
#     "workspace": "chenry:narrative_1624896051323",
#     "data": [
#       {
#         "authors": [
#           "chenry"
#         ],
#         "homepage": "https://escher.github.io",
#         "map_description": "Trehalose Uptake and Utilization\nLast Modified Mon Jun 28 2021 10:12:34 GMT-0500 (Central Daylight Time)",
#         "map_id": "o0u5z7uvvADq",
#         "map_name": "ModelSEED.Trehalose Uptake and Utilization",
#         "schema": "https://escher.github.io/escher/jsonschema/1-0-0#"
#       },
#       {
#         "canvas": {
#           "height": 2955.1708984375,
#           "width": 3878.602294921875,
#           "x": -1972.7403564453125,
#           "y": -1965.7877197265625
#         },
#         "nodes": {
#           "128": {
#             "node_type": "multimarker",
#             "x": 726.4398669111081,
#             "y": -498.55646274673427
#           },
#           "129": {
#             "node_type": "midmarker",
#             "x": 726.1957328167853,
#             "y": -478.5579528386436
#           },
#           "130": {
#             "node_type": "multimarker",
#             "x": 725.9515987224627,
#             "y": -458.5594429305537
#           },
#           "131": {
#             "bigg_id": "cpd00009",
#             "label_x": 595.1241280006554,
#             "label_y": -672.9238366953288,
#             "name": "Phosphate",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": 651.7052132057336,
#             "y": -652.8444909922038
#           },
#           "132": {
#             "bigg_id": "cpd00079",
#             "label_x": 53.95667170692832,
#             "label_y": -916.6572206313169,
#             "name": "D-glucose-6-phosphate",
#             "node_is_primary": 1,
#             "node_type": "metabolite",
#             "x": 170.07713984657676,
#             "y": -886.9013536269224
#           },
#           "134": {
#             "node_type": "multimarker",
#             "x": -319.57867901052066,
#             "y": 171.1279173430288
#           },
#           "135": {
#             "node_type": "midmarker",
#             "x": -319.7214359297375,
#             "y": 151.12842683796816
#           },
#           "136": {
#             "node_type": "multimarker",
#             "x": -319.86419284895516,
#             "y": 131.12893633290753
#           },
#           "137": {
#             "bigg_id": "cpd00001",
#             "label_x": -258.1650210373248,
#             "label_y": 339.9674909042991,
#             "name": "H2O",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": -235.86414823459037,
#             "y": 359.6665875839866
#           },
#           "140": {
#             "node_type": "multimarker",
#             "x": -480.43761201193445,
#             "y": 181.74286574056657
#           },
#           "141": {
#             "node_type": "midmarker",
#             "x": -480.5803689311517,
#             "y": 161.7433752355056
#           },
#           "142": {
#             "node_type": "multimarker",
#             "x": -480.72312585036894,
#             "y": 141.74388473044456
#           },
#           "143": {
#             "bigg_id": "cpd00001",
#             "label_x": -416.7082640086368,
#             "label_y": 345.7649417768837,
#             "name": "H2O",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": -384.9409300242618,
#             "y": 363.0974613081337
#           },
#           "144": {
#             "bigg_id": "cpd00190",
#             "label_x": -646.9545955944409,
#             "label_y": -4.236504055033379,
#             "name": "beta-D-Glucose",
#             "node_is_primary": 1,
#             "node_type": "metabolite",
#             "x": -484.36499598506595,
#             "y": -36.900930858622246
#           },
#           "145": {
#             "node_type": "multimarker",
#             "x": -1145.1760393492416,
#             "y": 89.50454256544703
#           },
#           "146": {
#             "node_type": "midmarker",
#             "x": -1145.3187962684594,
#             "y": 69.50505206038645
#           },
#           "147": {
#             "node_type": "multimarker",
#             "x": -1145.4615531876775,
#             "y": 49.505561555325585
#           },
#           "148": {
#             "bigg_id": "cpd00009",
#             "label_x": -1250.027214653807,
#             "label_y": 280.3794412131565,
#             "name": "Phosphate",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": -1192.3100515678696,
#             "y": 247.47439665749243
#           },
#           "151": {
#             "node_type": "multimarker",
#             "x": -1467.1934544944863,
#             "y": 28.254923128696248
#           },
#           "152": {
#             "node_type": "midmarker",
#             "x": -1467.3362114137042,
#             "y": 8.255432623634988
#           },
#           "153": {
#             "node_type": "multimarker",
#             "x": -1467.4789683329213,
#             "y": -11.744057881425135
#           },
#           "154": {
#             "bigg_id": "cpd00009",
#             "label_x": -1406.2805313309411,
#             "label_y": 242.6627759583165,
#             "name": "Phosphate",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": -1385.8996719559411,
#             "y": 209.22150703741806
#           },
#           "155": {
#             "bigg_id": "cpd00089",
#             "label_x": 86.51043740447187,
#             "label_y": -425.1109402130139,
#             "name": "Glucose-1-phosphate",
#             "node_is_primary": 1,
#             "node_type": "metabolite",
#             "x": 170.52293816741133,
#             "y": -468.0740444610608
#           },
#           "157": {
#             "node_type": "multimarker",
#             "x": 169.41657204347587,
#             "y": -623.0700958752818
#           },
#           "158": {
#             "node_type": "midmarker",
#             "x": 169.27381512425842,
#             "y": -643.0695863803421
#           },
#           "159": {
#             "node_type": "multimarker",
#             "x": 169.13105820504086,
#             "y": -663.0690768854031
#           },
#           "161": {
#             "node_type": "multimarker",
#             "x": -306.35875505469056,
#             "y": -32.36718582760784
#           },
#           "162": {
#             "node_type": "midmarker",
#             "x": -326.3582455597508,
#             "y": -32.22442890839022
#           },
#           "163": {
#             "node_type": "multimarker",
#             "x": -346.35773606481183,
#             "y": -32.08167198917289
#           },
#           "165": {
#             "node_type": "multimarker",
#             "x": 1238.5499498835754,
#             "y": -471.6830655679539
#           },
#           "166": {
#             "node_type": "midmarker",
#             "x": 1238.6927068027928,
#             "y": -451.68357506289374
#           },
#           "167": {
#             "node_type": "multimarker",
#             "x": 1238.8354637220107,
#             "y": -431.68408455783197
#           },
#           "168": {
#             "bigg_id": "cpd00001",
#             "label_x": 1119.4120678316579,
#             "label_y": -573.3786103305611,
#             "name": "H2O",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": 1157.9452709566579,
#             "y": -556.1098725375923
#           },
#           "171": {
#             "node_type": "multimarker",
#             "x": -3.75525974057075,
#             "y": -581.9632648605598
#           },
#           "172": {
#             "node_type": "midmarker",
#             "x": -3.898016659788425,
#             "y": -601.962755365621
#           },
#           "173": {
#             "node_type": "multimarker",
#             "x": -4.040773579005588,
#             "y": -621.9622458706815
#           },
#           "174": {
#             "bigg_id": "cpd00002",
#             "label_x": 45.49346643050512,
#             "label_y": -459.74062926849285,
#             "name": "ATP",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": 79.50221734603247,
#             "y": -494.9212628134147
#           },
#           "175": {
#             "bigg_id": "cpd00008",
#             "label_x": -72.40145402825101,
#             "label_y": -784.2597419596596,
#             "name": "ADP",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": -52.50270467674957,
#             "y": -768.717871842472
#           },
#           "176": {
#             "bigg_id": "cpd00067",
#             "label_x": -82.81624082496307,
#             "label_y": -724.959125149487,
#             "name": "H+",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": -66.20744565894745,
#             "y": -706.5206638457761
#           },
#           "178": {
#             "node_type": "multimarker",
#             "x": -807.5253756166439,
#             "y": -1459.1975846716564
#           },
#           "179": {
#             "node_type": "midmarker",
#             "x": -787.5253867696142,
#             "y": -1459.218706193511
#           },
#           "180": {
#             "node_type": "multimarker",
#             "x": -767.5253979225845,
#             "y": -1459.2398277153652
#           },
#           "181": {
#             "bigg_id": "cpd00794",
#             "label_x": -1314.1976524623747,
#             "label_y": -1490.561602838223,
#             "name": "TRHL",
#             "node_is_primary": 1,
#             "node_type": "metabolite",
#             "x": -1294.3952842983122,
#             "y": -1459.0338928772856
#           },
#           "182": {
#             "bigg_id": "cpd12508",
#             "label_x": -1016.9952513156566,
#             "label_y": -1559.019882966895,
#             "name": "Protein N-pros-phosphohistidine",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": -892.6098143039378,
#             "y": -1539.107773591895
#           },
#           "183": {
#             "bigg_id": "cpd11712",
#             "label_x": -667.6099314101258,
#             "label_y": -1539.3295495713646,
#             "name": "Protein histidine",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": -682.6099314101258,
#             "y": -1539.3295495713646
#           },
#           "23": {
#             "node_type": "multimarker",
#             "x": -508.67457771876377,
#             "y": -671.2000419076874
#           },
#           "24": {
#             "node_type": "midmarker",
#             "x": -508.8173346379814,
#             "y": -691.1995324127488
#           },
#           "25": {
#             "node_type": "multimarker",
#             "x": -508.96009155719815,
#             "y": -711.199022917809
#           },
#           "26": {
#             "bigg_id": "cpd00863",
#             "label_x": -700.7273468338901,
#             "label_y": -916.7966488384075,
#             "name": "beta-D-Glucose 6-phosphate",
#             "node_is_primary": 1,
#             "node_type": "metabolite",
#             "x": -509.8680023514683,
#             "y": -883.9860409282512
#           },
#           "27": {
#             "bigg_id": "cpd00001",
#             "label_x": 1450.0809242419762,
#             "label_y": -378.72200249635193,
#             "name": "H2O",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": 1459.4825355701012,
#             "y": -353.09053276978943
#           },
#           "28": {
#             "node_type": "multimarker",
#             "x": 1356.8750894456393,
#             "y": -216.8513150001187
#           },
#           "29": {
#             "node_type": "midmarker",
#             "x": 1357.0865680846982,
#             "y": -196.85243311174287
#           },
#           "30": {
#             "node_type": "multimarker",
#             "x": 1357.2980467237567,
#             "y": -176.85355122336597
#           },
#           "32": {
#             "bigg_id": "cpd00009",
#             "label_x": 1414.0228132451439,
#             "label_y": -46.06625392872036,
#             "name": "Phosphate",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": 1461.8465437138939,
#             "y": -83.35531261402309
#           },
#           "34": {
#             "bigg_id": "cpd00009",
#             "label_x": -531.0529174361916,
#             "label_y": -1340.082988953805,
#             "name": "Phosphate",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": -469.54595942837904,
#             "y": -1324.2364313366174
#           },
#           "35": {
#             "node_type": "multimarker",
#             "x": -369.32731343998125,
#             "y": -1205.9413595340516
#           },
#           "36": {
#             "node_type": "midmarker",
#             "x": -368.796182446255,
#             "y": -1185.948413281249
#           },
#           "37": {
#             "node_type": "multimarker",
#             "x": -368.26505145252844,
#             "y": -1165.9554670284465
#           },
#           "41": {
#             "bigg_id": "cpd00001",
#             "label_x": 239.52729258356726,
#             "label_y": 353.3448513244198,
#             "name": "H2O",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": 214.52729258356703,
#             "y": 353.3448513244198
#           },
#           "42": {
#             "node_type": "multimarker",
#             "x": 141.16514779240435,
#             "y": 162.13120601906843
#           },
#           "43": {
#             "node_type": "midmarker",
#             "x": 141.02239087318674,
#             "y": 142.13171551400717
#           },
#           "44": {
#             "node_type": "multimarker",
#             "x": 140.87963395396957,
#             "y": 122.13222500894659
#           },
#           "45": {
#             "bigg_id": "cpd00794",
#             "label_x": -313.16869173911607,
#             "label_y": 768.3308951937437,
#             "name": "TRHL",
#             "node_is_primary": 1,
#             "node_type": "metabolite",
#             "x": -282.5193387117723,
#             "y": 721.1040275179624
#           },
#           "46": {
#             "bigg_id": "cpd00027",
#             "label_x": 163.04640015425343,
#             "label_y": -3.5069500319831377,
#             "name": "D-Glucose",
#             "node_is_primary": 1,
#             "node_type": "metabolite",
#             "x": 139.77326783003468,
#             "y": -32.86382640527415
#           },
#           "47": {
#             "bigg_id": "cpd00001",
#             "label_x": -110.72861222806301,
#             "label_y": 334.9346620754792,
#             "name": "H2O",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": -86.02948503079739,
#             "y": 353.8676454739167
#           },
#           "48": {
#             "node_type": "multimarker",
#             "x": -147.27827931884073,
#             "y": 172.61649678537225
#           },
#           "49": {
#             "node_type": "midmarker",
#             "x": -147.4210362380585,
#             "y": 152.61700628031178
#           },
#           "50": {
#             "node_type": "multimarker",
#             "x": -147.56379315727588,
#             "y": 132.61751577525087
#           },
#           "52": {
#             "bigg_id": "cpd19001",
#             "label_x": -147.34064896822804,
#             "label_y": -6.862497531071995,
#             "name": "alpha-D-Glucose",
#             "node_is_primary": 1,
#             "node_type": "metabolite",
#             "x": -151.36270364046928,
#             "y": -33.473551951543186
#           },
#           "53": {
#             "bigg_id": "cpd00001",
#             "label_x": 354.3127670847796,
#             "label_y": -588.3587044799353,
#             "name": "H2O",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": 375.9383774363421,
#             "y": -574.5437020385291
#           },
#           "54": {
#             "node_type": "multimarker",
#             "x": 460.4502601000155,
#             "y": -530.3797905574959
#           },
#           "55": {
#             "node_type": "midmarker",
#             "x": 461.0295236651549,
#             "y": -510.38818097442095
#           },
#           "56": {
#             "node_type": "multimarker",
#             "x": 461.6087872302935,
#             "y": -490.3965713913451
#           },
#           "57": {
#             "bigg_id": "cpd00523",
#             "label_x": -297.1999914776901,
#             "label_y": -1492.2201767011693,
#             "name": "Trehalose 6-phosphate",
#             "node_is_primary": 1,
#             "node_type": "metabolite",
#             "x": -163.05344606753388,
#             "y": -1467.412498478513
#           },
#           "59": {
#             "bigg_id": "cpd19006",
#             "label_x": -273.0507108016394,
#             "label_y": -901.362610783382,
#             "name": "alpha-D-Glucose 6-phosphate",
#             "node_is_primary": 1,
#             "node_type": "metabolite",
#             "x": -146.40750325159055,
#             "y": -877.6539544723469
#           },
#           "60": {
#             "bigg_id": "cpd00001",
#             "label_x": 901.8193928418686,
#             "label_y": -599.7921096741553,
#             "name": "H2O",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": 932.0794026074939,
#             "y": -584.2502395569678
#           },
#           "61": {
#             "node_type": "multimarker",
#             "x": 993.6719663631184,
#             "y": -464.0151626502118
#           },
#           "62": {
#             "node_type": "midmarker",
#             "x": 992.9496680189698,
#             "y": -444.02820977834983
#           },
#           "63": {
#             "node_type": "multimarker",
#             "x": 992.2273696748202,
#             "y": -424.04125690648664
#           },
#           "74": {
#             "bigg_id": "cpd00009",
#             "label_x": -946.4598889557997,
#             "label_y": 322.8267878595425,
#             "name": "Phosphate",
#             "node_is_primary": 0,
#             "node_type": "metabolite",
#             "x": -881.6624036042372,
#             "y": 288.28928175602687
#           },
#           "75": {
#             "node_type": "multimarker",
#             "x": -813.2017943324561,
#             "y": 160.3679183489191
#           },
#           "76": {
#             "node_type": "midmarker",
#             "x": -813.3445512516737,
#             "y": 140.36842784385794
#           },
#           "77": {
#             "node_type": "multimarker",
#             "x": -813.4873081708906,
#             "y": 120.36893733879737
#           },
#           "79": {
#             "bigg_id": "cpd00501",
#             "label_x": -801.0160632223738,
#             "label_y": -474.13378566472807,
#             "name": "beta-D-Glucose 1-phosphate",
#             "node_is_primary": 1,
#             "node_type": "metabolite",
#             "x": -505.69736815401444,
#             "y": -453.85180324285307
#           }
#         },
#         "reactions": {
#           "11": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn15360"
#               ]
#             },
#             "bigg_id": "rxn15360",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": -798.3445512516737,
#             "label_y": 150.36842784385794,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00009",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00794",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00501",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd19001",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn15360",
#             "reversibility": 0,
#             "segments": {
#               "63": {
#                 "from_node_id": "75",
#                 "to_node_id": "76"
#               },
#               "64": {
#                 "from_node_id": "77",
#                 "to_node_id": "76"
#               },
#               "65": {
#                 "b1": {
#                   "x": -812.9020048021,
#                   "y": 202.36684840954695
#                 },
#                 "b2": {
#                   "x": -813.4006206332451,
#                   "y": 236.15056495917338
#                 },
#                 "from_node_id": "75",
#                 "to_node_id": "74"
#               },
#               "66": {
#                 "b1": {
#                   "x": -815.0389320586717,
#                   "y": 566.118540801016
#                 },
#                 "b2": {
#                   "x": -443.7117874305803,
#                   "y": 666.6940766849295
#                 },
#                 "from_node_id": "75",
#                 "to_node_id": "45"
#               },
#               "67": {
#                 "b1": {
#                   "x": -813.915396661286,
#                   "y": -386.23570025411004
#                 },
#                 "b2": {
#                   "x": -810.5882840771867,
#                   "y": -395.3935320623335
#                 },
#                 "from_node_id": "77",
#                 "to_node_id": "79"
#               },
#               "68": {
#                 "b1": {
#                   "x": -813.7464058670023,
#                   "y": -247.49979067920844
#                 },
#                 "b2": {
#                   "x": -270.56141152634405,
#                   "y": -167.17899249349625
#                 },
#                 "from_node_id": "77",
#                 "to_node_id": "52"
#               }
#             }
#           },
#           "18": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn04020"
#               ]
#             },
#             "bigg_id": "rxn04020",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": 587.8466727581915,
#             "label_y": -447.9583739812217,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00009",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00523",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00079",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd00501",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn04020",
#             "reversibility": 0,
#             "segments": {
#               "110": {
#                 "from_node_id": "128",
#                 "to_node_id": "129"
#               },
#               "111": {
#                 "from_node_id": "130",
#                 "to_node_id": "129"
#               },
#               "112": {
#                 "b1": {
#                   "x": 727.0013753280459,
#                   "y": -544.5530355353422
#                 },
#                 "b2": {
#                   "x": 713.2886176366467,
#                   "y": -618.3401898299051
#                 },
#                 "from_node_id": "128",
#                 "to_node_id": "131"
#               },
#               "113": {
#                 "b1": {
#                   "x": 726.9525485091817,
#                   "y": -540.5533335537236
#                 },
#                 "b2": {
#                   "x": 820.0480839966524,
#                   "y": -1375.5401783086495
#                 },
#                 "from_node_id": "128",
#                 "to_node_id": "57"
#               },
#               "114": {
#                 "b1": {
#                   "x": 724.9443516118838,
#                   "y": -169.87923484630193
#                 },
#                 "b2": {
#                   "x": 521.4761927293775,
#                   "y": -797.6411453689652
#                 },
#                 "from_node_id": "130",
#                 "to_node_id": "132"
#               },
#               "115": {
#                 "b1": {
#                   "x": 739.9868094420622,
#                   "y": -17.069490284414712
#                 },
#                 "b2": {
#                   "x": -330.40879557663004,
#                   "y": -262.65675623536754
#                 },
#                 "from_node_id": "130",
#                 "to_node_id": "79"
#               }
#             }
#           },
#           "19": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn27381"
#               ]
#             },
#             "bigg_id": "rxn27381",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": -304.7214359297375,
#             "label_y": 156.3952115059369,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00001",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00794",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00190",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd19001",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn27381",
#             "reversibility": 0,
#             "segments": {
#               "116": {
#                 "from_node_id": "134",
#                 "to_node_id": "135"
#               },
#               "117": {
#                 "from_node_id": "136",
#                 "to_node_id": "135"
#               },
#               "118": {
#                 "b1": {
#                   "x": -319.2503380963197,
#                   "y": 217.1267455046687
#                 },
#                 "b2": {
#                   "x": -295.95655801839104,
#                   "y": 295.57777202083184
#                 },
#                 "from_node_id": "134",
#                 "to_node_id": "137"
#               },
#               "119": {
#                 "b1": {
#                   "x": -322.44097152390003,
#                   "y": 433.2512168770626
#                 },
#                 "b2": {
#                   "x": -302.8848059811123,
#                   "y": 520.4967240722087
#                 },
#                 "from_node_id": "134",
#                 "to_node_id": "45"
#               },
#               "120": {
#                 "b1": {
#                   "x": -320.16398237931145,
#                   "y": 89.13000627228001
#                 },
#                 "b2": {
#                   "x": -344.2506523582745,
#                   "y": 30.31721963941112
#                 },
#                 "from_node_id": "136",
#                 "to_node_id": "144"
#               },
#               "121": {
#                 "b1": {
#                   "x": -320.1925337631551,
#                   "y": 85.1301081712678
#                 },
#                 "b2": {
#                   "x": -302.5683177975895,
#                   "y": 32.42050797270343
#                 },
#                 "from_node_id": "136",
#                 "to_node_id": "52"
#               }
#             }
#           },
#           "20": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn15001"
#               ]
#             },
#             "bigg_id": "rxn15001",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": -467.9470071147455,
#             "label_y": 178.8432287511306,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00001",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00794",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00190",
#                 "coefficient": 2
#               }
#             ],
#             "name": "rxn15001",
#             "reversibility": 0,
#             "segments": {
#               "122": {
#                 "from_node_id": "140",
#                 "to_node_id": "141"
#               },
#               "123": {
#                 "from_node_id": "142",
#                 "to_node_id": "141"
#               },
#               "124": {
#                 "b1": {
#                   "x": -480.1092710977338,
#                   "y": 227.7416939022056
#                 },
#                 "b2": {
#                   "x": -442.7005481828952,
#                   "y": 294.2584751908064
#                 },
#                 "from_node_id": "140",
#                 "to_node_id": "143"
#               },
#               "125": {
#                 "b1": {
#                   "x": -476.14955334460257,
#                   "y": 450.91528232971666
#                 },
#                 "b2": {
#                   "x": -418.8971909873158,
#                   "y": 514.2246672409382
#                 },
#                 "from_node_id": "140",
#                 "to_node_id": "45"
#               },
#               "126": {
#                 "b1": {
#                   "x": -481.02291538072615,
#                   "y": 99.74495466981756
#                 },
#                 "b2": {
#                   "x": -486.3629030896894,
#                   "y": 14.764792550139703
#                 },
#                 "from_node_id": "142",
#                 "to_node_id": "144"
#               }
#             }
#           },
#           "21": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn01966"
#               ]
#             },
#             "bigg_id": "rxn01966",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": -1130.3187962684594,
#             "label_y": 79.50505206038645,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00009",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00794",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00027",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd00501",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn01966",
#             "reversibility": 0,
#             "segments": {
#               "127": {
#                 "from_node_id": "145",
#                 "to_node_id": "146"
#               },
#               "128": {
#                 "from_node_id": "147",
#                 "to_node_id": "146"
#               },
#               "129": {
#                 "b1": {
#                   "x": -1144.8476984350423,
#                   "y": 135.5033707270868
#                 },
#                 "b2": {
#                   "x": -1151.1819416825135,
#                   "y": 190.2498073328478
#                 },
#                 "from_node_id": "145",
#                 "to_node_id": "148"
#               },
#               "130": {
#                 "b1": {
#                   "x": -1133.2001834416626,
#                   "y": 468.3054195915955
#                 },
#                 "b2": {
#                   "x": -864.7984658242251,
#                   "y": 609.5043515022024
#                 },
#                 "from_node_id": "145",
#                 "to_node_id": "45"
#               },
#               "131": {
#                 "b1": {
#                   "x": -1142.6367282999267,
#                   "y": -204.228035623616
#                 },
#                 "b2": {
#                   "x": -199.28507154592813,
#                   "y": -323.9361415873552
#                 },
#                 "from_node_id": "147",
#                 "to_node_id": "46"
#               },
#               "132": {
#                 "b1": {
#                   "x": -1155.2910883483376,
#                   "y": -461.57444236670074
#                 },
#                 "b2": {
#                   "x": -1144.9891439601668,
#                   "y": -457.6259943696118
#                 },
#                 "from_node_id": "147",
#                 "to_node_id": "79"
#               }
#             }
#           },
#           "22": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn39802"
#               ]
#             },
#             "bigg_id": "rxn39802",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": -1452.3362114137042,
#             "label_y": 18.255432623634988,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00009",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00794",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00089",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd19001",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn39802",
#             "reversibility": 1,
#             "segments": {
#               "133": {
#                 "from_node_id": "151",
#                 "to_node_id": "152"
#               },
#               "134": {
#                 "from_node_id": "153",
#                 "to_node_id": "152"
#               },
#               "135": {
#                 "b1": {
#                   "x": -1466.865113580288,
#                   "y": 74.2537512903362
#                 },
#                 "b2": {
#                   "x": -1448.2734541703617,
#                   "y": 157.07786872680794
#                 },
#                 "from_node_id": "151",
#                 "to_node_id": "154"
#               },
#               "136": {
#                 "b1": {
#                   "x": -1464.8767773648115,
#                   "y": 352.80915498113507
#                 },
#                 "b2": {
#                   "x": -1302.7277906505149,
#                   "y": 636.6682690741118
#                 },
#                 "from_node_id": "151",
#                 "to_node_id": "45"
#               },
#               "137": {
#                 "b1": {
#                   "x": -1481.9888463222383,
#                   "y": -395.0800025287731
#                 },
#                 "b2": {
#                   "x": 182.49091949761328,
#                   "y": -219.05916285411269
#                 },
#                 "from_node_id": "153",
#                 "to_node_id": "155"
#               },
#               "138": {
#                 "b1": {
#                   "x": -1468.6476795158308,
#                   "y": -175.4743228232553
#                 },
#                 "b2": {
#                   "x": -161.96315811524545,
#                   "y": -416.1073535150017
#                 },
#                 "from_node_id": "153",
#                 "to_node_id": "52"
#               }
#             }
#           },
#           "23": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn00704"
#               ]
#             },
#             "bigg_id": "rxn00704",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": 177.17309901021423,
#             "label_y": -658.0535646518265,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00089",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00079",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn00704",
#             "reversibility": 1,
#             "segments": {
#               "139": {
#                 "from_node_id": "157",
#                 "to_node_id": "158"
#               },
#               "140": {
#                 "from_node_id": "159",
#                 "to_node_id": "158"
#               },
#               "141": {
#                 "b1": {
#                   "x": 169.71636157383267,
#                   "y": -581.0711658146538
#                 },
#                 "b2": {
#                   "x": 170.10358971720984,
#                   "y": -526.8225478196769
#                 },
#                 "from_node_id": "157",
#                 "to_node_id": "155"
#               },
#               "142": {
#                 "b1": {
#                   "x": 168.83126867468457,
#                   "y": -705.0680069460307
#                 },
#                 "b2": {
#                   "x": 167.04949284305576,
#                   "y": -816.7649162192743
#                 },
#                 "from_node_id": "159",
#                 "to_node_id": "132"
#               }
#             }
#           },
#           "24": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn27702"
#               ]
#             },
#             "bigg_id": "rxn27702",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": -388.1316830597508,
#             "label_y": 10.189694626766027,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd19001",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00190",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn27702",
#             "reversibility": 1,
#             "segments": {
#               "143": {
#                 "from_node_id": "161",
#                 "to_node_id": "162"
#               },
#               "144": {
#                 "from_node_id": "163",
#                 "to_node_id": "162"
#               },
#               "145": {
#                 "b1": {
#                   "x": -264.3598249940628,
#                   "y": -32.66697535796425
#                 },
#                 "b2": {
#                   "x": -210.11120699908543,
#                   "y": -33.05420350134165
#                 },
#                 "from_node_id": "161",
#                 "to_node_id": "52"
#               },
#               "146": {
#                 "b1": {
#                   "x": -388.35666612543946,
#                   "y": -31.781882458816142
#                 },
#                 "b2": {
#                   "x": -428.47747020394485,
#                   "y": -31.495499043932682
#                 },
#                 "from_node_id": "163",
#                 "to_node_id": "144"
#               }
#             }
#           },
#           "25": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn00606"
#               ]
#             },
#             "bigg_id": "rxn00606",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": 1097.607806900449,
#             "label_y": -427.8685726214875,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00001",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00523",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00027",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd00079",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn00606",
#             "reversibility": 0,
#             "segments": {
#               "147": {
#                 "from_node_id": "165",
#                 "to_node_id": "166"
#               },
#               "148": {
#                 "from_node_id": "167",
#                 "to_node_id": "166"
#               },
#               "149": {
#                 "b1": {
#                   "x": 1226.5491699126678,
#                   "y": -514.6751306997644
#                 },
#                 "b2": {
#                   "x": 1220.1845938235256,
#                   "y": -522.8032787598758
#                 },
#                 "from_node_id": "165",
#                 "to_node_id": "168"
#               },
#               "150": {
#                 "b1": {
#                   "x": 1186.466996787297,
#                   "y": -805.6595065063484
#                 },
#                 "b2": {
#                   "x": 1124.5281316393618,
#                   "y": -1433.7033950004234
#                 },
#                 "from_node_id": "165",
#                 "to_node_id": "57"
#               },
#               "151": {
#                 "b1": {
#                   "x": 1247.6319232602566,
#                   "y": -18.46492233757533
#                 },
#                 "b2": {
#                   "x": 420.0720457855258,
#                   "y": -48.93400877681273
#                 },
#                 "from_node_id": "167",
#                 "to_node_id": "46"
#               },
#               "152": {
#                 "b1": {
#                   "x": 1238.0636044028054,
#                   "y": 28.699028242536315
#                 },
#                 "b2": {
#                   "x": 302.36991699757425,
#                   "y": -51.097834299862484
#                 },
#                 "from_node_id": "167",
#                 "to_node_id": "132"
#               }
#             }
#           },
#           "26": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn00216"
#               ]
#             },
#             "bigg_id": "rxn00216",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": 5.833855898805325,
#             "label_y": -578.7924215033163,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00002",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00027",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00008",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd00067",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd00079",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn00216",
#             "reversibility": 0,
#             "segments": {
#               "153": {
#                 "from_node_id": "171",
#                 "to_node_id": "172"
#               },
#               "154": {
#                 "from_node_id": "173",
#                 "to_node_id": "172"
#               },
#               "155": {
#                 "b1": {
#                   "x": -3.4269188263708656,
#                   "y": -535.9644366989198
#                 },
#                 "b2": {
#                   "x": 17.262894479164515,
#                   "y": -528.2278565911306
#                 },
#                 "from_node_id": "171",
#                 "to_node_id": "174"
#               },
#               "156": {
#                 "b1": {
#                   "x": 1.1150871010685819,
#                   "y": -268.68120997439064
#                 },
#                 "b2": {
#                   "x": -1.0000940527349371,
#                   "y": -195.97589500502886
#                 },
#                 "from_node_id": "171",
#                 "to_node_id": "46"
#               },
#               "157": {
#                 "b1": {
#                   "x": -4.340563109361881,
#                   "y": -663.9611759313093
#                 },
#                 "b2": {
#                   "x": -4.859371632479963,
#                   "y": -736.6477857326915
#                 },
#                 "from_node_id": "173",
#                 "to_node_id": "175"
#               },
#               "158": {
#                 "b1": {
#                   "x": -4.3691144932058705,
#                   "y": -667.9610740323212
#                 },
#                 "b2": {
#                   "x": -3.968122792079953,
#                   "y": -673.2140700680604
#                 },
#                 "from_node_id": "173",
#                 "to_node_id": "176"
#               },
#               "159": {
#                 "b1": {
#                   "x": -4.3691144932058705,
#                   "y": -667.9610740323212
#                 },
#                 "b2": {
#                   "x": 33.27360312630168,
#                   "y": -868.4057828804391
#                 },
#                 "from_node_id": "173",
#                 "to_node_id": "132"
#               }
#             }
#           },
#           "27": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn11965"
#               ]
#             },
#             "bigg_id": "rxn11965",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": -858.8115806172705,
#             "label_y": -1417.691118302886,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00794",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd12508",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00523",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd11712",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn11965",
#             "reversibility": 0,
#             "segments": {
#               "160": {
#                 "from_node_id": "178",
#                 "to_node_id": "179"
#               },
#               "161": {
#                 "from_node_id": "180",
#                 "to_node_id": "179"
#               },
#               "162": {
#                 "b1": {
#                   "x": -849.5253521954066,
#                   "y": -1459.1532294757626
#                 },
#                 "b2": {
#                   "x": -1235.6453170601617,
#                   "y": -1459.0959373477326
#                 },
#                 "from_node_id": "178",
#                 "to_node_id": "181"
#               },
#               "163": {
#                 "b1": {
#                   "x": -853.5253499648127,
#                   "y": -1459.149005171391
#                 },
#                 "b2": {
#                   "x": -858.7943564068271,
#                   "y": -1477.1434507342321
#                 },
#                 "from_node_id": "178",
#                 "to_node_id": "182"
#               },
#               "164": {
#                 "b1": {
#                   "x": -725.525421343822,
#                   "y": -1459.2841829112592
#                 },
#                 "b2": {
#                   "x": -503.22016359683073,
#                   "y": -1454.810447697263
#                 },
#                 "from_node_id": "180",
#                 "to_node_id": "57"
#               },
#               "165": {
#                 "b1": {
#                   "x": -721.525423574416,
#                   "y": -1459.2884072156298
#                 },
#                 "b2": {
#                   "x": -716.2944358717396,
#                   "y": -1477.2939415774435
#                 },
#                 "from_node_id": "180",
#                 "to_node_id": "183"
#               }
#             }
#           },
#           "3": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn01967"
#               ]
#             },
#             "bigg_id": "rxn01967",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": -652.6898321965753,
#             "label_y": -658.75013055728,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00501",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00863",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn01967",
#             "reversibility": 1,
#             "segments": {
#               "19": {
#                 "from_node_id": "23",
#                 "to_node_id": "24"
#               },
#               "20": {
#                 "from_node_id": "25",
#                 "to_node_id": "24"
#               },
#               "21": {
# ...
#                 "b2": {
#                   "x": -505.19875824628224,
#                   "y": -515.8052208256784
#                 },
#                 "from_node_id": "23",
#                 "to_node_id": "79"
#               },
#               "22": {
#                 "b1": {
#                   "x": -509.2598810875547,
#                   "y": -753.1979529784359
#                 },
#                 "b2": {
#                   "x": -509.4486539012666,
#                   "y": -825.2375375696347
#                 },
#                 "from_node_id": "25",
#                 "to_node_id": "26"
#               }
#             }
#           },
#           "4": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn02004"
#               ]
#             },
#             "bigg_id": "rxn02004",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": 1206.3065387878232,
#             "label_y": -183.3986825013913,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00001",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00523",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00009",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd00794",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn02004",
#             "reversibility": 1,
#             "segments": {
#               "23": {
#                 "from_node_id": "28",
#                 "to_node_id": "29"
#               },
#               "24": {
#                 "from_node_id": "30",
#                 "to_node_id": "29"
#               },
#               "25": {
#                 "b1": {
#                   "x": 1356.4309843036165,
#                   "y": -258.8489669657092
#                 },
#                 "b2": {
#                   "x": 1366.483827679275,
#                   "y": -284.82919985565877
#                 },
#                 "from_node_id": "28",
#                 "to_node_id": "27"
#               },
#               "26": {
#                 "b1": {
#                   "x": 1371.5807610321535,
#                   "y": -1083.28759176581
#                 },
#                 "b2": {
#                   "x": 1226.1805426173148,
#                   "y": -1408.2694084322843
#                 },
#                 "from_node_id": "28",
#                 "to_node_id": "57"
#               },
#               "27": {
#                 "b1": {
#                   "x": 1357.784447593591,
#                   "y": -130.856122880101
#                 },
#                 "b2": {
#                   "x": 1394.112790876443,
#                   "y": -125.75782393665509
#                 },
#                 "from_node_id": "30",
#                 "to_node_id": "32"
#               },
#               "28": {
#                 "b1": {
#                   "x": 1362.8900857905458,
#                   "y": 465.56070036020515
#                 },
#                 "b2": {
#                   "x": 859.3356632188836,
#                   "y": 678.4004524640743
#                 },
#                 "from_node_id": "30",
#                 "to_node_id": "45"
#               }
#             }
#           },
#           "5": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn15550"
#               ]
#             },
#             "bigg_id": "rxn15550",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": -353.796182446255,
#             "label_y": -1175.948413281249,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00009",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00523",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00501",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd19006",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn15550",
#             "reversibility": 0,
#             "segments": {
#               "29": {
#                 "from_node_id": "35",
#                 "to_node_id": "36"
#               },
#               "30": {
#                 "from_node_id": "37",
#                 "to_node_id": "36"
#               },
#               "31": {
#                 "b1": {
#                   "x": -370.4426885268074,
#                   "y": -1247.926546664939
#                 },
#                 "b2": {
#                   "x": -385.6192338103945,
#                   "y": -1267.8136642781812
#                 },
#                 "from_node_id": "35",
#                 "to_node_id": "34"
#               },
#               "32": {
#                 "b1": {
#                   "x": -370.5489147255523,
#                   "y": -1251.9251359155
#                 },
#                 "b2": {
#                   "x": -375.823801988804,
#                   "y": -1444.6754263271105
#                 },
#                 "from_node_id": "35",
#                 "to_node_id": "57"
#               },
#               "33": {
#                 "b1": {
#                   "x": -360.0092845622239,
#                   "y": -942.7660128005407
#                 },
#                 "b2": {
#                   "x": -355.2586345871893,
#                   "y": -447.11649165239726
#                 },
#                 "from_node_id": "37",
#                 "to_node_id": "79"
#               },
#               "34": {
#                 "b1": {
#                   "x": -363.3480536904281,
#                   "y": -1011.8296177354371
#                 },
#                 "b2": {
#                   "x": -145.7802623808946,
#                   "y": -1081.3492531582183
#                 },
#                 "from_node_id": "37",
#                 "to_node_id": "59"
#               }
#             }
#           },
#           "6": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn00007"
#               ]
#             },
#             "bigg_id": "rxn00007",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": 156.02239087318674,
#             "label_y": 152.13171551400717,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00001",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00794",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00027",
#                 "coefficient": 2
#               }
#             ],
#             "name": "rxn00007",
#             "reversibility": 0,
#             "segments": {
#               "35": {
#                 "from_node_id": "42",
#                 "to_node_id": "43"
#               },
#               "36": {
#                 "from_node_id": "44",
#                 "to_node_id": "43"
#               },
#               "37": {
#                 "b1": {
#                   "x": 141.46493732276087,
#                   "y": 204.13013607969572
#                 },
#                 "b2": {
#                   "x": 184.7647785661136,
#                   "y": 300.68308625021416
#                 },
#                 "from_node_id": "42",
#                 "to_node_id": "41"
#               },
#               "38": {
#                 "b1": {
#                   "x": 135.55938372394957,
#                   "y": 371.4737932598574
#                 },
#                 "b2": {
#                   "x": -89.04496567211203,
#                   "y": 537.4120833259697
#                 },
#                 "from_node_id": "42",
#                 "to_node_id": "45"
#               },
#               "39": {
#                 "b1": {
#                   "x": 140.57984442361283,
#                   "y": 80.13329494831913
#                 },
#                 "b2": {
#                   "x": 140.1926162802353,
#                   "y": 25.88467695334191
#                 },
#                 "from_node_id": "44",
#                 "to_node_id": "46"
#               }
#             }
#           },
#           "7": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn15002"
#               ]
#             },
#             "bigg_id": "rxn15002",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": -132.4210362380585,
#             "label_y": 162.61700628031178,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00001",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00794",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd19001",
#                 "coefficient": 2
#               }
#             ],
#             "name": "rxn15002",
#             "reversibility": 0,
#             "segments": {
#               "40": {
#                 "from_node_id": "48",
#                 "to_node_id": "49"
#               },
#               "41": {
#                 "from_node_id": "50",
#                 "to_node_id": "49"
#               },
#               "42": {
#                 "b1": {
#                   "x": -146.97848978848435,
#                   "y": 214.6154268460001
#                 },
#                 "b2": {
#                   "x": -138.6022551454331,
#                   "y": 280.1473958743396
#                 },
#                 "from_node_id": "48",
#                 "to_node_id": "47"
#               },
#               "43": {
#                 "b1": {
#                   "x": -150.19651315219696,
#                   "y": 426.9069882686275
#                 },
#                 "b2": {
#                   "x": -187.0574379463652,
#                   "y": 527.2690881177577
#                 },
#                 "from_node_id": "48",
#                 "to_node_id": "45"
#               },
#               "44": {
#                 "b1": {
#                   "x": -147.86358268763212,
#                   "y": 90.61858571462335
#                 },
#                 "b2": {
#                   "x": -150.94335519026782,
#                   "y": 25.274951407073218
#                 },
#                 "from_node_id": "50",
#                 "to_node_id": "52"
#               }
#             }
#           },
#           "8": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn15073"
#               ]
#             },
#             "bigg_id": "rxn15073",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": 325.79136448546785,
#             "label_y": -502.1150486502022,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00001",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00523",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd19001",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd19006",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn15073",
#             "reversibility": 0,
#             "segments": {
#               "45": {
#                 "from_node_id": "54",
#                 "to_node_id": "55"
#               },
#               "46": {
#                 "from_node_id": "56",
#                 "to_node_id": "55"
#               },
#               "47": {
#                 "b1": {
#                   "x": 459.23380661322403,
#                   "y": -572.3621706819536
#                 },
#                 "b2": {
#                   "x": 419.89185839135166,
#                   "y": -566.0772409033098
#                 },
#                 "from_node_id": "54",
#                 "to_node_id": "53"
#               },
#               "48": {
#                 "b1": {
#                   "x": 469.76499580054497,
#                   "y": -734.2045868148613
#                 },
#                 "b2": {
#                   "x": 420.9004861161609,
#                   "y": -1325.42250633603
#                 },
#                 "from_node_id": "54",
#                 "to_node_id": "57"
#               },
#               "49": {
#                 "b1": {
#                   "x": 467.41523995547277,
#                   "y": -135.26551467705264
#                 },
#                 "b2": {
#                   "x": -151.7179611273582,
#                   "y": -90.6084443210026
#                 },
#                 "from_node_id": "56",
#                 "to_node_id": "52"
#               },
#               "50": {
#                 "b1": {
#                   "x": 466.0184269690129,
#                   "y": -343.1836691042963
#                 },
#                 "b2": {
#                   "x": -147.79583415560683,
#                   "y": -86.22376102068574
#                 },
#                 "from_node_id": "56",
#                 "to_node_id": "59"
#               }
#             }
#           },
#           "9": {
#             "annotation": {
#               "seed.compartment": "0:",
#               "seed.reaction": [
#                 "rxn15074"
#               ]
#             },
#             "bigg_id": "rxn15074",
#             "gene_reaction_rule": "",
#             "genes": [],
#             "label_x": 847.499289601001,
#             "label_y": -443.07897576956077,
#             "metabolites": [
#               {
#                 "bigg_id": "cpd00001",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00523",
#                 "coefficient": -1
#               },
#               {
#                 "bigg_id": "cpd00190",
#                 "coefficient": 1
#               },
#               {
#                 "bigg_id": "cpd00863",
#                 "coefficient": 1
#               }
#             ],
#             "name": "rxn15074",
#             "reversibility": 0,
#             "segments": {
#               "51": {
#                 "from_node_id": "61",
#                 "to_node_id": "62"
#               },
#               "52": {
#                 "from_node_id": "63",
#                 "to_node_id": "62"
#               },
#               "53": {
#                 "b1": {
#                   "x": 995.1887928858303,
#                   "y": -505.98776368112203
#                 },
#                 "b2": {
#                   "x": 966.1220490835387,
#                   "y": -552.2771973496905
#                 },
#                 "from_node_id": "61",
#                 "to_node_id": "60"
#               },
#               "54": {
#                 "b1": {
#                   "x": 995.3332525546605,
#                   "y": -509.9851542554959
#                 },
#                 "b2": {
#                   "x": 1025.9280625372724,
#                   "y": -1448.2928525657912
#                 },
#                 "from_node_id": "61",
#                 "to_node_id": "57"
#               },
#               "55": {
#                 "b1": {
#                   "x": 1010.0502298091608,
#                   "y": 18.100369624800464
#                 },
#                 "b2": {
#                   "x": -485.08246458989004,
#                   "y": -258.44648920187296
#                 },
#                 "from_node_id": "63",
#                 "to_node_id": "144"
#               },
#               "56": {
#                 "b1": {
#                   "x": 1002.2199901155616,
#                   "y": -64.97295004201362
#                 },
#                 "b2": {
#                   "x": -363.77958626698234,
#                   "y": -173.9041479277123
#                 },
#                 "from_node_id": "63",
#                 "to_node_id": "26"
#               }
#             }
#           }
#         },
#         "text_labels": {
#           "0": {
#             "text": "Trehalose Uptake and Utilization",
#             "x": -546.1895847320557,
#             "y": -1679.045654296875
#           },
#           "4": {
#             "text": "Transport from Extracellular Space",
#             "x": -1631.62109375,
#             "y": -1353.325439453125
#           },
#           "5": {
#             "text": "Trehalose",
#             "x": -409.69854736328125,
#             "y": 871.13037109375
#           }
#         }
#       }
#     ]
#   }
# ]
