# %%
import modelseed_escher
import escher
import json
import math

# %%
data = None
with open('../../../data/escher/maps/ModelSEED/ModelSEED.Alanine Biosynthesis.json', 'r') as f:
    data = json.loads(f.read())

# %%
for k in data[1].keys():
    print(k, type(data[1][k]))
# Out:
# reactions <class 'dict'>
# nodes <class 'dict'>
# text_labels <class 'dict'>
# canvas <class 'dict'>

# %%
# %run ../src/modelseed_escher/core/escher_map.py

# %%
escher_map = EscherMap.from_json('../../../data/escher/maps/BIOS/bios7.Nucleotides.json')

# %%
escher_map.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="rmacktjdfn"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
# ...

# %%
escher_map.add_reaction ...

# %%
escher_map.display_in_notebook()
# Out:
# IPython.core.display.HTML

# %%
escher_map.add_reaction({'0':{'a' : -1, 'b' : 1}}, 0, 0, 3 * math.pi / 2, 500, 't1', 't2', escher_map.escher_graph, 0, None, None, None, None)
# Out:
# ['a', 'b']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-b259b4092c3a> in <module>()
# ----> 1 escher_map.add_reaction({'0':{'a' : -1, 'b' : 1}}, 0, 0, 3 * math.pi / 2, 500, 't1', 't2', escher_map.escher_graph, 0, None, None, None, None)
#
# ~/workspace/jupyter/python3/modelseed-escher/src/modelseed_escher/core/escher_map.py in add_reaction(self, stoich, x_coord, y_coord, orient, reaction_length, prim_react, prim_prod, layout, rxn_numb, cc_coords, cc, prev_prod, prev_id)
#     125
#     126         # Check to see if either node is chained
# --> 127         if prim_react['bigg_id'] not in cc or (prev_prod == prim_react['bigg_id'] or prev_prod == None):
#     128             # check to see if product is chained
#     129             if prim_prod['bigg_id'] in cc and (prev_prod != None and prev_prod != prim_react['bigg_id']):
#
# ...
