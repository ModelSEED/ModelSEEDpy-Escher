# %%
import escher
import modelseed_escher
from modelseed_escher.escher_map_grid import EscherGrid
import logging
import copy

logger = logging.getLogger(__name__)

# %%
escher_manager = modelseed_escher.EscherManager(escher)

# %%
em1 = escher_manager.get_map('ModelSEED', 'ModelSEED', 'Chorismate Synthesis')
em2 = escher_manager.get_map('ModelSEED', 'ModelSEED', 'Phenylalanine and Tyrosine Branches from Chorismate')
em3 = escher_manager.get_map('ModelSEED', 'ModelSEED', 'Fatty Acid Biosynthesis II Aesthetically Improved')

# %%
grid = EscherGrid()
em_grid = grid.build([em1, em2, em1, em2], (2, 2))
b = escher.Builder(map_json=json.dumps(em_grid.escher_map), model_json=None)
b.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="qsdswcdxzs"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
# ...
