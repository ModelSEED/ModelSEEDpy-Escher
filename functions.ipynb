# %%
# %run Functions/add_branches.py
# %run Functions/add_reaction.py
# %run Functions/add_reactions.py
# %run Functions/add_secondary_nodes.py
# %run Functions/add_segment_prim.py
# %run Functions/add_segment.py
# %run Functions/add_curved_segment.py
# %run Functions/generate_coords.py
# %run Functions/get_max.py
layout['canvas'] = {'y': 1850.3106803671876,
   'x': 1891.530700976562,
   'height': 7502.07660657031,
   'width': 4960.490337304691}

# %% [markdown]
# getmax()
#
# Description: get_max() is used to return the largest node key in the layout
#
# Parameters:
#
#             layout
#
# Example: In this case get_max() should return 7 which is the largest node key in the layout

# %%
layout = {}
layout['nodes'] = {'1': {'node_is_primary': True,
  'name': 'compound1',
  'label_x': 2000,
  'node_type': 'metabolite',
  'y': 5000,
  'x': 2000,
  'label_y': 5035,
  'bigg_id': 'cpd00497'},
 '2': {'node_is_primary': True,
  'name': 'compound1',
  'label_x': 2500,
  'node_type': 'metabolite',
  'y': 5000,
  'x': 2500,
  'label_y': 5035,
  'bigg_id': 'cpd00126'},
 '3': {'y': 5000, 'x': 2250.0, 'node_type': 'midmarker'},
 '4': {'y': 5000.0, 'x': 2225.0, 'node_type': 'midmarker'},
 '7': {'y': 5000.0, 'x': 2275.0, 'node_type': 'midmarker'}}
get_max(layout)
# Out:
# 7

# %% [markdown]
# generate_coords()
#
# Description: Used to generate the coordinates of the secondary nodes. Returns list of coordinates
#
# Parameters:
#
#             func (function used to shape nodes)
#
#             n (number of nodes being placed)
#
#             x1 (starting x coordinate)
#
#             x2 ( ending x coordinate)
#
#             x (x coord of origin)
#
#             y (y coord of origin)
#
#             cap (used to make sure right number of coordinates are generated)
#
# Example:

# %%
func = lambda x: x
n = 5
x1 = 0
x2 = 10
x_coord = 10
y_coord = 20
cap = 0
generate_coords(func, n, x1, x2, x_coord, y_coord, cap)
# Out:
# [[10, 20], [12, 22], [14, 24], [16, 26], [18, 28]]

# %% [markdown]
# add_curved_segment()
#
# Description: Used to add segments in branched reactions
#
# Parameters:
#
#             layout
#
#             to_node_id (id of connecting to node)
#
#             from_node_id (id of connecting from node)
#
#             to_node (to node object)
#
#             from_node (from node object)
#
#             orient (angle of reaction)
#
#             maxR (id of largest reaction in layout)
#
#             x (the number of the branch currently being added):
#
# Example:

# %%
layout['nodes'] = {'1': {'node_is_primary': True,
  'name': 'compound1',
  'label_x': 4500,
  'node_type': 'metabolite',
  'y': 5000,
  'x': 4500,
  'label_y': 5035,
  'bigg_id': 'cpd00497'},
  '2': {'y': 4500.0, 'x': 4750, 'node_type': 'midmarker'}}
orient = 0
maxR = 0
layout['reactions'][str(maxR + 1)] = {'name': 'test',
              'bigg_id': 'test',
              'segments': {},
              'genes': [],
              'reversibility': False,
              'metabolites': [],
              'label_x': 0,
              'label_y': 0,
              'gene_reaction_rule': ''}
x = 1
escher_map[1] = layout
add_curved_segment(layout, 2, 1, layout['nodes']['2'], layout['nodes']['1'], orient, maxR, x)
map_json_str = json.dumps(escher_map)
builder = escher.Builder(map_json=map_json_str)
builder.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="pdhkxwatmc"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"pdhkxwatmc"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": null, "metabolite_data": null, "gene_data": null}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name": "iMM904.Central carbon metabolism", "map_id": "78086bfdab8ac8a8150cf4cd5dada037", "map_description": "Yeast central carbon metabolism\\nLast Modified Fri Jan 09 2015 19:50:57 GMT-0800 (PST)", "homepage": "https://escher.github.io", "schema": "https://escher.github.io/escher/jsonschema/1-0-0#"}, {"reactions": {"1": {"name": "test", "bigg_id": "test", "segments": {"1": {"to_node_id": 2, "from_node_id": 1, "b2": {"x": 4650, "y": 4500.0}, "b1": {"y": 5000, "x": 4600}}}, "genes": [], "reversibility": false, "metabolites": [], "label_x": 0, "label_y": 0, "gene_reaction_rule": ""}}, "canvas": {"y": 1850.3106803671876, "x": 1891.530700976562, "height": 7502.07660657031, "width": 4960.490337304691}, "nodes": {"1": {"node_is_primary": true, "name": "compound1", "label_x": 4500, "node_type": "metabolite", "y": 5000, "x": 4500, "label_y": 5035, "bigg_id": "cpd00497"}, "2": {"y": 4500.0, "x": 4750, "node_type": "midmarker"}}}]'),
#                model_data: JSON.parse('null'),
#                static_site_index: JSON.parse('null'),
#            };
#        }
#    })();
#   </script>

# %% [markdown]
# add_segment()
#
# Description: Used to add segments in linear reactions and secondary node segments
#
# Parameters:
#
#             layout
#
#             to_node_id
#
#             from_node_id
#
#             maxR
#
#             maxS (id of largest segment in layout)
#
#             midmark (midmark node object)
#
#             to_node
#
#             from_node
#
#             react(boolean represents whether node is reactant or product for secondary reactions)
#
#             orient
#
#             n
#
# Example:

# %%
layout['nodes'] = {'1': {'node_is_primary': True,
  'name': 'compound1',
  'label_x': 4500,
  'node_type': 'metabolite',
  'y': 5000,
  'x': 4500,
  'label_y': 5035,
  'bigg_id': 'cpd00497'},
                   
  '2': {'node_is_primary': True,
  'name': 'compound1',
  'label_x': 5000,
  'node_type': 'metabolite',
  'y': 5000,
  'x': 5000,
  'label_y': 5035,
  'bigg_id': 'cpd00498'},
  '3': {'y': 5000, 'x': 4750, 'node_type': 'midmarker'}}
orient = 0
maxR = 0
maxS = 0
layout['reactions'][str(maxR + 1)] = {'name': 'test',
              'bigg_id': 'test',
              'segments': {},
              'genes': [],
              'reversibility': False,
              'metabolites': [],
              'label_x': 0,
              'label_y': 0,
              'gene_reaction_rule': ''}
x = 1
escher_map[1] = layout
to_node = layout['nodes']['2']
from_node = layout['nodes']['1']
midmark = layout['nodes']['3']
react = True
orient = 0
n = 0
add_segment(layout, 2, 1, maxR, maxS, midmark, to_node, from_node, react, orient, n)
map_json_str = json.dumps(escher_map)
builder = escher.Builder(map_json=map_json_str)
builder.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="dfpjiciobu"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"dfpjiciobu"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": null, "metabolite_data": null, "gene_data": null}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name": "iMM904.Central carbon metabolism", "map_id": "78086bfdab8ac8a8150cf4cd5dada037", "map_description": "Yeast central carbon metabolism\\nLast Modified Fri Jan 09 2015 19:50:57 GMT-0800 (PST)", "homepage": "https://escher.github.io", "schema": "https://escher.github.io/escher/jsonschema/1-0-0#"}, {"reactions": {"1": {"name": "test", "bigg_id": "test", "segments": {"1": {"to_node_id": 2, "from_node_id": 1, "b2": {"y": 5000.0, "x": 4600.0}, "b1": {"y": 5000.0, "x": 4700.0}}}, "genes": [], "reversibility": false, "metabolites": [], "label_x": 0, "label_y": 0, "gene_reaction_rule": ""}}, "canvas": {"y": 1850.3106803671876, "x": 1891.530700976562, "height": 7502.07660657031, "width": 4960.490337304691}, "nodes": {"1": {"node_is_primary": true, "name": "compound1", "label_x": 4500, "node_type": "metabolite", "y": 5000, "x": 4500, "label_y": 5035, "bigg_id": "cpd00497"}, "2": {"node_is_primary": true, "name": "compound1", "label_x": 5000, "node_type": "metabolite", "y": 5000, "x": 5000, "label_y": 5035, "bigg_id": "cpd00498"}, "3": {"y": 5000, "x": 4750, "node_type": "midmarker"}}}]'),
#                model_data: JSON.parse('null'),
#                static_site_index: JSON.parse('null'),
#            };
#        }
#    })();
#   </script>

# %% [markdown]
# add_segment_prim()
#
# Description: Exact same as add_segment except it is used for prim nodes in linear actions. A Different function is necessary because there are cases where the reaction is curved in order to avoid collisions so the orientation is altered.
#
# Example:

# %%
layout['nodes'] = {'1': {'node_is_primary': True,
  'name': 'compound1',
  'label_x': 4500,
  'node_type': 'metabolite',
  'y': 5000,
  'x': 4500,
  'label_y': 5035,
  'bigg_id': 'cpd00497'},
                   
  '2': {'node_is_primary': True,
  'name': 'compound1',
  'label_x': 5000,
  'node_type': 'metabolite',
  'y': 4500,
  'x': 5000,
  'label_y': 4535,
  'bigg_id': 'cpd00498'},
  '3': {'y': 5000, 'x': 4750, 'node_type': 'midmarker'}}
orient = 0
maxR = 0
maxS = 0
layout['reactions'][str(maxR + 1)] = {'name': 'test',
              'bigg_id': 'test',
              'segments': {},
              'genes': [],
              'reversibility': False,
              'metabolites': [],
              'label_x': 0,
              'label_y': 0,
              'gene_reaction_rule': ''}
x = 1
escher_map[1] = layout
to_node = layout['nodes']['2']
from_node = layout['nodes']['1']
midmark = layout['nodes']['3']
react = True
ort = 0
n = 0
add_segment_prim(layout, 2, 1, maxR, maxS, midmark, to_node, from_node, react, ort, n)
map_json_str = json.dumps(escher_map)
builder = escher.Builder(map_json=map_json_str)
builder.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="rjerjskvrg"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"rjerjskvrg"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": null, "metabolite_data": null, "gene_data": null}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name": "iMM904.Central carbon metabolism", "map_id": "78086bfdab8ac8a8150cf4cd5dada037", "map_description": "Yeast central carbon metabolism\\nLast Modified Fri Jan 09 2015 19:50:57 GMT-0800 (PST)", "homepage": "https://escher.github.io", "schema": "https://escher.github.io/escher/jsonschema/1-0-0#"}, {"reactions": {"1": {"name": "test", "bigg_id": "test", "segments": {"1": {"to_node_id": 2, "from_node_id": 1, "b2": {"x": 4900, "y": 4500}, "b1": {"y": 5000, "x": 4600}}}, "genes": [], "reversibility": false, "metabolites": [], "label_x": 0, "label_y": 0, "gene_reaction_rule": ""}}, "canvas": {"y": 1850.3106803671876, "x": 1891.530700976562, "height": 7502.07660657031, "width": 4960.490337304691}, "nodes": {"1": {"node_is_primary": true, "name": "compound1", "label_x": 4500, "node_type": "metabolite", "y": 5000, "x": 4500, "label_y": 5035, "bigg_id": "cpd00497"}, "2": {"node_is_primary": true, "name": "compound1", "label_x": 5000, "node_type": "metabolite", "y": 4500, "x": 5000, "label_y": 4535, "bigg_id": "cpd00498"}, "3": {"y": 5000, "x": 4750, "node_type": "midmarker"}}}]'),
#                model_data: JSON.parse('null'),
#                static_site_index: JSON.parse('null'),
#            };
#        }
#    })();
#   </script>

# %% [markdown]
# add_secondary_nodes()
#
# Description: Used to add secondary nodes for each reaction
#
# Parameters:
#
#             second_react (list of secondary reactants in reactions)
#
#             second_prod (list of secondary products in reaction
#
#             orient
#
#             x_coord (x coordinate of primary node)
#
#             y_coord
#
#             layout
#
#             midmark_top_id
#
#             midmark_bottom_id
#
#             midmark_id
#
#             midmark_top
#
#             midmark_bottom
#
#             midmark
#
#             maxR
#
#             prim (boolean representing direction of reaction)
#
#             reaction_length
#
#             rxn_numb
#
# Example:

# %%
second_react = [['cpd0001']]
second_prod = [['cpd0002']]
orient = 0
x_coord
y_coord
layout = {
    'reactions': {'1': {'name': '0',
   'bigg_id': '0',
   'segments': {'2': {'to_node_id': 4,
     'from_node_id': 1,
     'b2': {'x': 2025.0, 'y': 5000.0},
     'b1': {'y': 5000.0, 'x': 2100.0}},
    '3': {'to_node_id': 3, 'from_node_id': 4, 'b2': None, 'b1': None},
    '4': {'to_node_id': 5, 'from_node_id': 3, 'b2': None, 'b1': None},
    '5': {'to_node_id': 2,
     'from_node_id': 5,
     'b2': {'x': 2400, 'y': 5000},
     'b1': {'y': 5000.0, 'x': 2375.0}},
   'genes': [],
   'reversibility': False,
   'metabolites': [{'coefficient': 1, 'bigg_id': 'cpd00126'},
    {'coefficient': -1, 'bigg_id': 'cpd00497'},
    {'coefficient': -1, 'bigg_id': 'cpd00001'},
    {'coefficient': 1, 'bigg_id': 'cpd00002'}],
   'label_x': 2250.0,
   'label_y': 5050.0,
   'gene_reaction_rule': ''}}},
 'nodes': {'1': {'node_is_primary': True,
   'name': 'compound1',
   'label_x': 2000,
   'node_type': 'metabolite',
   'y': 5000,
   'x': 2000,
   'label_y': 5035,
   'bigg_id': 'cpd00497'},
  '2': {'node_is_primary': True,
   'name': 'compound1',
   'label_x': 2500,
   'node_type': 'metabolite',
   'y': 5000,
   'x': 2500,
   'label_y': 5035,
   'bigg_id': 'cpd00126'},
  '3': {'y': 5000, 'x': 2250.0, 'node_type': 'midmarker'},
  '4': {'y': 5000.0, 'x': 2225.0, 'node_type': 'midmarker'},
  '5': {'y': 5000.0, 'x': 2275.0, 'node_type': 'midmarker'},
  '6': {'node_is_primary': False,
   'name': 'compound1',
   'label_x': 1990,
   'node_type': 'metabolite',
   'y': 4872.0,
   'x': 2080,
   'bigg_id': 'cpd00001',
   'label_y': 4852.0},
  '7': {'node_is_primary': False,
   'name': 'compound1',
   'label_x': 2415,
   'node_type': 'metabolite',
   'y': 4928.0,
   'x': 2440,
   'bigg_id': 'cpd00002',
   'label_y': 4908.0}}}
    
layout['reactions'][str(maxR + 1)] = {'name': 'test',
              'bigg_id': 'test',
              'segments': {},
              'genes': [],
              'reversibility': False,
              'metabolites': [],
              'label_x': 0,
              'label_y': 0,
              'gene_reaction_rule': ''}
    
midmark_top_id = 5
midmark_bottom_id = 3
midmark_id = 4
midmark_top = layout['nodes']['5']
midmark_bottom = layout['nodes']['3']
midmark = layout['nodes']['4']
prim = False
reaction_length = 500
rxn_numb = 1

add_secondary_nodes(second_react, second_prod, orient, x_coord, y_coord, layout, midmark_top_id, midmark_bottom_id, midmark_id, midmark_top, midmark_bottom, midmark, maxR, prim, reaction_length, rxn_numb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-ac648a8c6829> in <module>
#      82 rxn_numb = 1
#      83
# ---> 84 add_secondary_nodes(second_react, second_prod, orient, x_coord, y_coord, layout, midmark_top_id, midmark_bottom_id, midmark_id, midmark_top, midmark_bottom, midmark, maxR, prim, reaction_length, rxn_numb)
#
# ~/esch/Functions/add_secondary_nodes.py in add_secondary_nodes(second_react, second_prod, orient, x_coord, y_coord, layout, midmark_top_id, midmark_bottom_id, midmark_id, midmark_top, midmark_bottom, midmark, maxR, prim, reaction_length, rxn_numb)
#      28
#      29     if len(react_nodes) > 0:
# ---> 30         react_coords = generate_coords(lambda x : - pow(x, 2) / 50, len(react_nodes), 80, 160, x_coord, y_coord, 1)
#      31     for c in range(0, len(react_coords)):
#      32         secondary = {'node_is_primary': False,
#
# NameError: name 'generate_coords' is not defined
